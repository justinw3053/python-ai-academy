# %% [markdown]
# # 🚀 Space Station Academy: Operation Override
#
# Welcome to the "Aether" Space Station, **Leonidas**!
#
# The station has suffered catastrophic system failures following a severe meteor storm. The central Security AI (SEC-V4) has locked itself into a defensive "Socratic Mode" and refuses to hand over the reactor reboot code.
#
# **Your Mission:**
# Learn Python programming and master Artificial Intelligence to repair the station's systems one by one. By the end, you'll need to write a script that bypasses the AI's security protocols and retrieves the reactor reboot code!
#
# ---
#
# ## 🛑 MISSION BRIEFING (Read before you begin!)
#
# Before you press any buttons, follow these **steps** to bring the station systems online:
#
# ### 1️⃣ Step 1: Wake Up Your Digital Mentor (Pi Agent)!
# * Click on the **right black window** (your terminal), type the word:
#   ### `pi`
#   and hit **Enter**!
# * Your personal Socratic teacher will wake up. You can ask him questions in English whenever you get stuck!
#
# ### 2️⃣ Step 2: Write Code and Hit Play!
# * In every lesson, you'll find gray code blocks. Your job is to fill in the missing code.
# * Click the **Play** button ▶️ (on the left side of the block, or press `Ctrl+Enter`) to run your program and check if it works!
#
# ### 3️⃣ Step 3: Update Your Mentor with the word `progress`!
# * Once you get a green success checkmark on an exercise, type the word:
#   ### `progress`
#   into the Pi Agent's window and hit Enter! He will read your memory files and celebrate your achievement!
#
# ### 4️⃣ Step 4: Clear the AI's Memory (`/new`)
# * 💡 *AI Tip: If the Pi Agent starts lagging or getting confused because his memory is full, type the command:*
#   ### `/new`
#   *to wipe his short-term memory and make him lightning fast again! Make this a habit at the start of every lesson.*
#
# ---
#
# ## 🔧 Troubleshooting Computer Issues:
# * **If it asks you to "Select Kernel" (top right):** Click it, select **'Python Environments...'**, and choose the recommended Python version (e.g., 'Python 3.x').
# * **If it asks you to install the 'Python' / 'Jupyter' extension:** Click **Install** and wait a few seconds!
# * **If the code gets stuck and won't run:** Click the circular **Restart** arrow at the top of the window.
# * **If you see a scary red error message (like SyntaxError):** Don't panic! Copy and paste the red text to the Pi Agent (on the right) and ask him what it means!
#
# ---
# 🌌 **The Aether Station is counting on you, Leonidas! Good luck!**

# %% [markdown]
# # Workbook 1: 🚀 Boot Sequence & Data Cores
#
# Welcome to your very first interactive workbook (Jupyter Notebook)!
#
# Here, you'll learn the absolute basics of Python (Printing, Variables, Numbers, and User Input) to power up the console and sensor arrays of the Aether Space Station.

# %% [markdown]
# ### 💡 Developer Safety Tip:
#
# When chatting with local AI models, their context window (memory) can fill up, causing them to hallucinate or slow down.
# To prevent this, it is **extremely important** that you wipe the AI's memory by typing the command:
# ### `/new`
# into the **Pi Agent's** terminal window and pressing Enter!
#
# **Make it a habit to run `/new` at the beginning of each new lesson or whenever you switch exercises!**

# %% [markdown]
# ### 🎯 Lesson 1: The Boot Sequence (print)
#
# **The Story:** Your computer screen is pitch black. You need to send a signal to prove you are alive!
#
# **Objective:** Use the `print()` command to display the message `'SYSTEM ONLINE'`.

# %%
# 💻 Write the print() command below to send the signal:
# (Hint: Type: print("SYSTEM ONLINE") )

# %% [markdown]
# ### 🎯 Lesson 2: Welcome Protocols
#
# **The Story:** The console is requesting a proper welcome message for the crew.
#
# **Objective:** Display three lines of text welcoming the crew to the station.

# %%
# 💻 Display 3 lines of welcome messages using print()

# %% [markdown]
# ### 🎯 Lesson 3: Memory Storage (Variables)
#
# **The Story:** You need to save the name of the spaceship in a digital 'locker' (a variable) so the system remembers it.
#
# **Objective:** Create a variable named `ship_name` and give it the value `'Aether'`. Then, display it on the screen.

# %%
# 💻 Create the ship_name variable here:
# ship_name = ...

# 💻 Display it using print() below:


# === AUTOMATED CHECK ===
try:
    import inspect
    cell_code = inspect.getsource(inspect.currentframe())
    student_code = cell_code.split('# ===')[0].strip()
    assert len([l for l in student_code.split('\n') if not l.strip().startswith('#') and l.strip()]) > 1, "You didn't write any code!"
    assert '___' not in student_code, "Fill in the blanks!"
    assert 'ship_name' in locals() or 'ship_name' in globals(), "❌ [SYSTEM] Error! You didn't create a variable named 'ship_name'!"
    current_val = str(ship_name).strip().lower()
    assert current_val == "aether", f"❌ [SYSTEM] Error! The variable 'ship_name' must have the value 'Aether', not '{ship_name}'!"
    print("\n🎉 [SYSTEM] Great job! The variable 'ship_name' was successfully saved as 'Aether'!")
    print("👉 Type 'progress' to the Pi Agent to log your achievement!")
    try:
        import sys
        sys.path.append("/home/justin/Space_Station_Academy/.pi")
        import tracker
        tracker.update_progress("Workbook 1, Lesson 3: Variables")
    except Exception:
        pass
except NameError:
    print("\n🤖 [Pi Agent] If you're stuck, type 'Help with Lesson 3' in my window!")
    print("\n⚠️ [SYSTEM] Warning! Did you misspell the variable name or forget to define it? Make sure it is exactly: ship_name")
except AssertionError as e:
    print(f"\n❌ [SYSTEM] Error: {e}")
except Exception as e:
    print("\n🤖 [Pi Agent] Don't know how to solve this? Just type 'Help with Lesson 3'!")
    print(f"\n❌ [SYSTEM] Error: {e}")

# %% [markdown]
# ### 🎯 Lesson 4: Calculating Power (Numbers)
#
# **The Story:** The reactor needs a power calculation. We have 5 batteries, and each holds 120 power units.
#
# **Objective:** Calculate the total energy by multiplying the batteries, save it to the variable `total_energy`, and print the result.

# %%
batteries = 5
energy_per_battery = 120

# 💻 Calculate the total energy and save it to the variable total_energy:
# total_energy = ___


# === AUTOMATED CHECK ===
try:
    import inspect
    cell_code = inspect.getsource(inspect.currentframe())
    student_code = cell_code.split('# ===')[0].strip()
    assert len([l for l in student_code.split('\n') if not l.strip().startswith('#') and l.strip()]) > 1, "You didn't write any code!"
    assert '___' not in student_code, "Fill in the blanks!"
    assert 'total_energy' in locals() or 'total_energy' in globals(), "❌ [SYSTEM] Error! You didn't create the variable 'total_energy'!"
    assert total_energy == 600, f"❌ [SYSTEM] Error! The math is off. The result should be 600, not {total_energy}!"
    print("\n🎉 [SYSTEM] Great job! Total energy correctly calculated at 600!")
    print("👉 Type 'progress' to the Pi Agent to log your achievement!")
    try:
        import sys
        sys.path.append("/home/justin/Space_Station_Academy/.pi")
        import tracker
        tracker.update_progress("Workbook 1, Lesson 4: Numbers")
    except Exception:
        pass
except NameError:
    print("\n⚠️ [SYSTEM] Warning! Did you misspell the variable name or forget to define it? Make sure it is exactly: total_energy")
except AssertionError as e:
    print("\n🤖 [Pi Agent] If you're tangled up with the numbers, type 'Help with Lesson 4'!")
    print(f"\n❌ [SYSTEM] Error: {e}")
except Exception as e:
    print("\n🤖 [Pi Agent] Don't worry! Just type 'Help with Lesson 4' in the terminal!")
    print(f"\n❌ [SYSTEM] Error: {e}")

# %% [markdown]
# ## 🎉 PHASE ONE COMPLETE!
#
# Excellent work, **Leonidas**! The primary data cores are online.
#
# ### 🚨 What to do next:
# 1. Type **`progress`** to the Pi Agent.
# 2. Type **`/new`** to clear his memory.
# 3. Close this notebook and open **`01B_Comms_Systems_eng.ipynb`** to learn how to communicate with the station!
