# %% [markdown]
# # Αποστολή 2: 🛡️ Μήτρα Αποφάσεων & Λογική
#
# Καλώς όρισες στο δεύτερο αποστολή σου!
#
# Εδώ θα μάθεις πώς να παίρνει το πρόγραμμά σου αποφάσεις χρησιμοποιώντας Booleans (True / False), If, Elif, Else, και Λογικούς Τελεστές (and, or, not). Αυτά είναι απαραίτητα για να ελέγχεις αν η πίεση του οξυγόνου είναι ασφαλής και να ανοιγοκλείνεις τις θύρες ασφαλείας του σταθμού Aether.

# %% [markdown]
# ### 🎯 Μάθημα 9: Booleans (Αληθές / Ψευδές)
#
# **Η Ιστορία:** Η ενέργεια του σταθμού είναι στο 80%. Πρέπει να ελέγξουμε αν είναι πάνω από το όριο ασφαλείας (50%) και να αποθηκεύσουμε το αποτέλεσμα.
#
# **Στόχος:** Δημιούργησε μια μεταβλητή `is_safe` και δώσε της την τιμή της σύγκρισης `80 > 50`.

# %%
energeia = 80

# 💻 Δημιούργησε τη μεταβλητή is_safe και βάλε τη σύγκριση energeia > 50:


# === AUTOMATED CHECK ===
try:
    assert 'is_safe' in locals(), "❌ [SYSTEM] Error! Δεν δημιούργησες τη μεταβλητή 'is_safe'!"
    assert is_safe == True, "❌ [SYSTEM] Error! Η σύγκριση είναι εσφαλμένη. Έλεγξε αν η ενέργεια (80) είναι μεγαλύτερη από το όριο (50)!"
    print("\n🎉 [SYSTEM] Great job! Η σύγκριση Booleans έγινε σωστά, η κατάσταση είναι Ασφαλής (True)!")
    print("👉 Type 'progress' to the Pi Agent για να δει τι κατάφερες!")
    
    # Καταγραφή Προόδου
    try:
        import sys
        sys.path.append("/home/justin/Space_Station_Academy/.pi")
        import tracker
        tracker.update_progress("Mission 2, Μάθημα 9: Booleans")
    except Exception:
        pass
except AssertionError as e:
    print("\n🤖 [Pi Agent] Don't be discouraged! Type 'Help' in the side window so we can solve it together!")
    print(f"\n❌ [SYSTEM] Error: {e}")
except Exception as e:
    print("\n🤖 [Pi Agent] Something went wrong with the code. Type 'Help' so we can look at it!")
    print(f"\n❌ [SYSTEM] Error: {e}")

# %% [markdown]
# ### 📦 Το Μυστικό του Κουτιού (Indentation)!
#
# Πριν ξεκινήσουμε τις αποφάσεις, πρέπει να ξέρεις κάτι σημαντικό! Στην Python, όταν θέλουμε να βάλουμε εντολές *μέσα* σε μια απόφαση (if), χρησιμοποιούμε **Indentation** (πατώντας το πλήκτρο **Tab** στο πληκτρολόγιο, ή 4 κενά).
#
# Φαντάσου το σαν ένα **Κουτί**: Ό,τι είναι πιο μέσα (έχει κενό από αριστερά), βρίσκεται *μέσα* στο κουτί του `if`!
#
# ---
#
# ### 🎯 Μάθημα 10: Η εντολή If
#
# **Η Ιστορία:** Αν οι ασπίδες είναι κάτω από 20%, πρέπει να εκπέμψουμε σήμα κινδύνου!
#
# **Στόχος:** Γράψε μια εντολή `if` που θα εμφανίζει `'ΚΙΝΔΥΝΟΣ!'` αν οι ασπίδες είναι κάτω από 20.

# %%
aspides = 15

# 💻 Γράψε το if από κάτω. Μην ξεχάσεις την άνω-κάτω τελεία (:) και το space (indentation) στην επόμενη γραμμή!


# === AUTOMATED CHECK ===
try:
    import inspect
    cell_code = inspect.getsource(inspect.currentframe())
    student_code = cell_code.split('# ===')[0].strip()
    assert len([l for l in student_code.split('\n') if not l.strip().startswith('#') and l.strip()]) > 1, "Δεν έγραψες κώδικα! / You didn't write any code!"
    assert '___' not in student_code, "Συμπλήρωσε τα κενά! / Fill in the blanks!"
    print("\n🎉 [SYSTEM] Great job! Χρησιμοποίησες την εντολή 'if' για να ελέγξεις τις ασπίδες!")
    print("👉 Type 'progress' to the Pi Agent!")
    try:
        import sys
        sys.path.append("/home/justin/Space_Station_Academy/.pi")
        import tracker
        tracker.update_progress("Mission 2, Μάθημα 10: If Command")
    except Exception:
        pass
except Exception as e:
    print("\n🤖 [Pi Agent] Something went wrong with the code. Type 'Help' so we can look at it!")
    print(f"\n❌ [SYSTEM] Error: {e}")

# %% [markdown]
# ### 🎯 Μάθημα 11: Η εντολή Else
#
# **Η Ιστορία:** Αν ο αντιδραστήρας είναι σταθερός, όλα είναι καλά. Аλλιώς (else), πρέπει να ενεργοποιήσουμε τις εφεδρικές γεννήτριες.
#
# **Στόχος:** Χρησιμοποίησε `if` και `else` για να ελέγξεις τη μεταβλητή `statheros`.

# %%
statheros = False

# 💻 Συμπλήρωσε το if/else από κάτω:
# if statheros == True:
#     ...
# else:
#     ...


# === AUTOMATED CHECK ===
try:
    import inspect
    cell_code = inspect.getsource(inspect.currentframe())
    student_code = cell_code.split('# ===')[0].strip()
    assert len([l for l in student_code.split('\n') if not l.strip().startswith('#') and l.strip()]) > 1, "Δεν έγραψες κώδικα! / You didn't write any code!"
    assert '___' not in student_code, "Συμπλήρωσε τα κενά! / Fill in the blanks!"
    print("\n🎉 [SYSTEM] Φανταστικά! Χρησιμοποίησες την 'else' για να ελέγξεις τον αντιδραστήρας!")
    print("👉 Type 'progress' to the Pi Agent!")
    try:
        import sys
        sys.path.append("/home/justin/Space_Station_Academy/.pi")
        import tracker
        tracker.update_progress("Mission 2, Μάθημα 11: Else Command")
    except Exception:
        pass
except Exception as e:
    print("\n🤖 [Pi Agent] Something went wrong with the code. Type 'Help' so we can look at it!")
    print(f"\n❌ [SYSTEM] Error: {e}")

# %% [markdown]
# ### 🎯 Μάθημα 12: Πολλαπλές Διακλαδώσεις (elif)
#
# **Η Ιστορία:** Η θερμοκρασία του κινητήρα μπορεί να είναι: Χαμηλή (κάτω από 50), Κανονική (50 έως 100), ή Υπερβολική (πάνω από 100).
#
# **Στόχος:** Χρησιμοποίησε `if`, `elif`, και `else` για να κατηγοριοποιήσεις τη θερμοκρασία `120`.

# %%
thermokrasia = 120

# 💻 Γράψε τις συνθήκες εδώ. Αν είναι κάτω από 50 εκτύπωσε 'Χαμηλή', 
# αν είναι μεταξύ 50 και 100 εκτύπωσε 'Κανονική', αλλιώς εκτύπωσε 'Υπερβολική':


# === AUTOMATED CHECK ===
try:
    import inspect
    cell_code = inspect.getsource(inspect.currentframe())
    student_code = cell_code.split('# ===')[0].strip()
    assert len([l for l in student_code.split('\n') if not l.strip().startswith('#') and l.strip()]) > 1, "Δεν έγραψες κώδικα! / You didn't write any code!"
    assert '___' not in student_code, "Συμπλήρωσε τα κενά! / Fill in the blanks!"
    print("\n🎉 [SYSTEM] Εξαιρετικά! Χρησιμοποίησες την 'elif' για πολλαπλές διακλαδώσεις!")
    print("👉 Type 'progress' to the Pi Agent!")
    try:
        import sys
        sys.path.append("/home/justin/Space_Station_Academy/.pi")
        import tracker
        tracker.update_progress("Mission 2, Μάθημα 12: Elif Command")
    except Exception:
        pass
except Exception as e:
    print("\n🤖 [Pi Agent] Something went wrong with the code. Type 'Help' so we can look at it!")
    print(f"\n❌ [SYSTEM] Error: {e}")

# %% [markdown]
# ### 🎯 Μάθημα 13: Nested Logic (If μέσα σε If)
#
# **Η Ιστορία:** Για να ανοίξει η αεροστεγής πόρτα, πρέπει πρώτα να υπάρχει οξυγόνο ΚΑΙ μετά να πατηθεί το κουμπί έγκρισης.
#
# **Στόχος:** Γράψε ένα nested `if` (ένα `if` μέσα σε άλλο `if`) που ελέγχει αν υπάρχει οξυγόνο και αν η έγκριση είναι True. Αν ισχύουν και τα δύο, αποθήκευσε `True` στη μεταβλητή `door_open`.

# %%
oxygeno = True
egkrisi = True
door_open = False

# 💻 Γράψε το nested if εδώ για να θέσεις τη door_open σε True μόνο αν και τα δύο ισχύουν:


# === AUTOMATED CHECK ===
try:
    assert 'door_open' in locals(), "❌ [SYSTEM] Error! Δεν δημιούργησες τη μεταβλητή 'door_open'!"
    assert door_open == True, "❌ [SYSTEM] Error! Η πόρτα πρέπει να είναι ανοιχτή (door_open = True). Έλεγξες και τις δύο συνθήκες;"
    print("\n🎉 [SYSTEM] Great job! Η πόρτα άνοιξε με ασφάλεια (door_open = True)!")
    print("👉 Type 'progress' to the Pi Agent για να δει τι κατάφερες!")
    
    # Καταγραφή Προόδου
    try:
        import sys
        sys.path.append("/home/justin/Space_Station_Academy/.pi")
        import tracker
        tracker.update_progress("Mission 2, Μάθημα 13: Nested Logic")
    except Exception:
        pass
except AssertionError as e:
    print("\n🤖 [Pi Agent] Don't be discouraged! Type 'Help' in the side window so we can solve it together!")
    print(f"\n❌ [SYSTEM] Error: {e}")
except Exception as e:
    print("\n🤖 [Pi Agent] Something went wrong with the code. Type 'Help' so we can look at it!")
    print(f"\n❌ [SYSTEM] Error: {e}")

# %% [markdown]
# ### 🎯 Μάθημα 14: Λογικοί Τελεστές (and / or / not)
#
# **Η Ιστορία:** Μπορούμε να συνδυαστούμε συνθήκες χρησιμοποιώντας τις λέξεις `and` (και) ή `or` (ή) στην ίδια γραμμή!
#
# **Στόχος:** Έλεγξε αν η ενέργεια είναι πάνω από 50 ΚΑΙ οι ασπίδες είναι πάνω από 50. Αν ναι, αποθήκευσε `True` στη μεταβλητή `takeoff_permission`.

# %%
energeia = 60
aspides = 70
takeoff_permission = False

# 💻 Χρησιμοποίησε το 'and' στην ίδια συνθήκη if για να θέσεις την takeoff_permission σε True:


# === AUTOMATED CHECK ===
try:
    assert 'takeoff_permission' in locals(), "❌ [SYSTEM] Error! Δεν δημιούργησες τη μεταβλητή 'takeoff_permission'!"
    assert takeoff_permission == True, "❌ [SYSTEM] Error! Η άδεια απογείωσης πρέπει να είναι True. Χρησιμοποίησες σωστά το 'and';"
    print("\n🎉 [SYSTEM] Great job! Η άδεια απογείωσης δόθηκε με επιτυχία!")
    print("👉 Type 'progress' to the Pi Agent για να δει τι κατάφερες!")
    
    # Καταγραφή Προόδου
    try:
        import sys
        sys.path.append("/home/justin/Space_Station_Academy/.pi")
        import tracker
        tracker.update_progress("Mission 2, Μάθημα 14: Logical Operators")
    except Exception:
        pass
except AssertionError as e:
    print("\n🤖 [Pi Agent] Don't be discouraged! Type 'Help' in the side window so we can solve it together!")
    print(f"\n❌ [SYSTEM] Error: {e}")
except Exception as e:
    print("\n🤖 [Pi Agent] Something went wrong with the code. Type 'Help' so we can look at it!")
    print(f"\n❌ [SYSTEM] Error: {e}")

# %% [markdown]
# ## 🎉 Η ΑΠΟΣΤΟΛΗ ΟΛΟΚΛΗΡΩΘΗΚΕ! (Mission Completed)
#
# Εξαιρετική δουλειά, **Λεωνίδα**! Επισκεύασες τις πύλες ασφαλείας και τις ασπίδες του σταθμού χρησιμοποιώντας λογικές συνθήκες!
#
# ### 🚨 Τι πρέπει να κάνεις τώρα:
# 1. Γράψε **`πρόοδος`** στον Pi Agent για να συγχρονίσει την επιτυχία σου.
# 2. Γράψε **`/new`** για να αναζωογονήσεις τον δάσκαλό σου.
# 3. Κάνε κλικ στο κουμπί **ΕΠΟΜΕΝΟ ΜΑΘΗΜΑ (NEXT)** για να ξεκινήσεις τις επαναλήψεις και τη σάρωση ραντάρ!
