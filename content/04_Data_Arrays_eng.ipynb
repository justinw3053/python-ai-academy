# %% [markdown]
# # Mission 4: 📦 Συστοιχίες & Λεξικά Δεδομένων
#
# Ήρθε η ώρα να διαχειριστείς μεγάλες ομάδες δεδομένων! Θα μάθεις πώς να χρησιμοποιείς Λίστες (Lists) για αποθήκευση αποθεμάτων και Λεξικά (Dictionaries) για ταυτότητες και βάσεις δεδομένων.

# %% [markdown]
# ### 💡 Συμβουλή Ασφαλείας AI (Developer Tip):
#
# Ξεκινάμε μια νέα, μεγάλη ενότητα με Λίστες και Λεξικά!
# Before writing your code, **run the `/new` command in the Pi Agent chat window** to clear its history and ensure your assistant is 100% focused and fast!

# %% [markdown]
# ### 🎯 Μάθημα 21: Δημιουργία Λίστας
#
# **Η Ιστορία:** Μια λίστα είναι σαν ένα τρένο με βαγόνια όπου μπορούμε να αποθηκεύσουμε πολλά πράγματα μαζί!
#
# **Στόχος:** Φτιάξε μια λίστα με όνομα `tools` που περιέχει τα εξής κείμενα: `'screwdriver'`, `'hammer'`, `'flashlight'`.

# %%
# 💻 Φτιάξε τη λίστα tools από κάτω:


# === AUTOMATED CHECK ===
try:
    assert 'tools' in locals(), "❌ [SYSTEM] Error! Δεν δημιούργησες τη λίστα 'tools'!"
    assert len(tools) == 3, f"❌ [SYSTEM] Error! Η λίστα περιέχει {len(tools)} στοιχεία, ενώ πρέπει να περιέχει ακριβώς 3!"
    assert "screwdriver" in tools and "hammer" in tools and "flashlight" in tools, "❌ [SYSTEM] Error! Η λίστα πρέπει να περιέχει ακριβώς τα στοιχεία: 'screwdriver', 'hammer', 'flashlight'!"
    print("\n🎉 [SYSTEM] Great job! Η λίστα 'tools' δημιουργήθηκε σωστά με 3 βαγόνια!")
    print("👉 Type 'progress' to the Pi Agent για να δει τι κατάφερες!")
    
    # Καταγραφή Προόδου
    try:
        import sys
        sys.path.append("/home/justin/Space_Station_Academy/.pi")
        import tracker
        tracker.update_progress("Mission 4, Μάθημα 21: Lists")
    except Exception:
        pass
except AssertionError as e:
    print("\n🤖 [Pi Agent] Don't be discouraged! Type 'Help' in the side window so we can solve it together!")
    print(f"\n❌ [SYSTEM] Error: {e}")
except Exception as e:
    print("\n🤖 [Pi Agent] Something went wrong with the code. Type 'Help' so we can look at it!")
    print(f"\n❌ [SYSTEM] Error: {e}")

# %% [markdown]
# ### 🎯 Μάθημα 22: Indexing (Θέσεις στη Λίστα)
#
# **Η Ιστορία:** Κάθε αντικείμενο στη λίστα έχει μια θέση (index) που ξεκινάει ΠΑΝΤΑ από το 0!
#
# **Στόχος:** Εμφάνισε το πρώσο αντικείμενο της λίστας (θέση 0) και το τρίτο αντικείμενο (θέση 2).

# %%
devices = ["radar", "shield", "engine"]

# 💻 Εμφάνισε το 1ο και το 3ο στοιχείο της λίστας devices χρησιμοποιώντας [index]:

# %% [markdown]
# ### 🎯 Μάθημα 23: Μέθοδοι Λίστας (append & remove)
#
# **Η Ιστορία:** Μπορούμε να προσθέσουμε στοιχεία στη λίστα με την `.append()` ή να αφαιρέσουμε με την `.remove()`.
#
# **Στόχος:** Πρόσθεσε το στοιχείο `'laser'` στη λίστα και αφαίρεσε το στοιχείο `'hammer'`.

# %%
armory = ["hammer", "cannon"]

# 💻 Κάνε append το 'laser' και remove το 'hammer', μετά εμφάνισε τη λίστα:


# === AUTOMATED CHECK ===
try:
    assert 'armory' in locals(), "❌ [SYSTEM] Error! Η λίστα 'armory' δεν υπάρχει!"
    assert "laser" in armory, "❌ [SYSTEM] Error! Δεν πρόσθεσες το 'laser' στο οπλοστάσιο!"
    assert "hammer" not in armory, "❌ [SYSTEM] Error! Δεν αφαίρεσες το 'hammer' από το οπλοστάσιο!"
    print("\n🎉 [SYSTEM] Great job! Το οπλοστάσιο ενημερώθηκε τέλεια με το laser!")
    print("👉 Type 'progress' to the Pi Agent για να δει τι κατάφερες!")
    
    # Καταγραφή Προόδου
    try:
        import sys
        sys.path.append("/home/justin/Space_Station_Academy/.pi")
        import tracker
        tracker.update_progress("Mission 4, Μάθημα 23: List Methods")
    except Exception:
        pass
except AssertionError as e:
    print("\n🤖 [Pi Agent] Don't be discouraged! Type 'Help' in the side window so we can solve it together!")
    print(f"\n❌ [SYSTEM] Error: {e}")
except Exception as e:
    print("\n🤖 [Pi Agent] Something went wrong with the code. Type 'Help' so we can look at it!")
    print(f"\n❌ [SYSTEM] Error: {e}")

# %% [markdown]
# ### 🎯 Μάθημα 24: Λεξικά (Dictionaries)
#
# **Η Ιστορία:** Ένα λεξικό (dictionary) αποθηκεύει πληροφορίες σε ζευγάρια: Κλειδί (Key) και Τιμή (Value) - σαν μια ταυτότητα!
#
# **Στόχος:** Φτιάξε ένα λεξικό με όνομα `captain` με κλειδιά `'name'` (τιμή `'Alexis'`) και `'rank'` (τιμή `'Captain'`). Μετά εκτύπωσε μόνο το όνομα.

# %%
# 💻 Φτιάξε το λεξικό captain από κάτω, μετά εκτύπωσε μόνο το όνομα:


# === AUTOMATED CHECK ===
try:
    assert 'captain' in locals(), "❌ [SYSTEM] Error! Δεν δημιούργησες το λεξικό 'captain'!"
    assert captain.get("name") == "Alexis", f"❌ [SYSTEM] Error! Το wrench 'name' πρέπει να έχει τιμή 'Alexis', όχι '{captain.get('name')}'!"
    assert captain.get("rank") == "Captain", f"❌ [SYSTEM] Error! Το wrench 'rank' πρέπει να έχει τιμή 'Captain', όχι '{captain.get('rank')}'!"
    print("\n🎉 [SYSTEM] Great job! Το λεξικό του κυβερνήτη δημιουργήθηκε με επιτυχία!")
    print("👉 Type 'progress' to the Pi Agent για να δει τι κατάφερες!")
    
    # Καταγραφή Προόδου
    try:
        import sys
        sys.path.append("/home/justin/Space_Station_Academy/.pi")
        import tracker
        tracker.update_progress("Mission 4, Μάθημα 24: Dictionaries")
    except Exception:
        pass
except AssertionError as e:
    print("\n🤖 [Pi Agent] Don't be discouraged! Type 'Help' in the side window so we can solve it together!")
    print(f"\n❌ [SYSTEM] Error: {e}")
except Exception as e:
    print("\n🤖 [Pi Agent] Something went wrong with the code. Type 'Help' so we can look at it!")
    print(f"\n❌ [SYSTEM] Error: {e}")

# %% [markdown]
# ### 🎯 Μάθημα 25: Ενημέρωση Λεξικού
#
# **Η Ιστορία:** Μπορούμε να αλλάξουμε τιμές σε ένα λεξικό ή να προσθέσουμε νέα κλειδιά πολύ εύκολα.
#
# **Στόχος:** Άλλαξε την κατάσταση της shieldς σε `'ACTIVE'` και πρόσθεσε ένα νέο wrench `'power'` με τιμή `100`.

# %%
shield_stats = {
    "status": "INACTIVE"
}

# 💻 Άλλαξε την κατάσταση σε 'ACTIVE' και πρόσθεσε το wrench 'power' με τιμή 100, μετά εμφάνισε το λεξικό:


# === AUTOMATED CHECK ===
try:
    assert shield_stats.get("status") == "ACTIVE", "❌ [SYSTEM] Error! Η κατάσταση της shieldς πρέπει να είναι 'ACTIVE'!"
    assert shield_stats.get("power") == 100, "❌ [SYSTEM] Error! Δεν πρόσθεσες το wrench 'power' με τιμή 100!"
    print("\n🎉 [SYSTEM] Great job! Οι ασπίδες αναβαθμίστηκαν στο 100%!")
    print("👉 Type 'progress' to the Pi Agent για να δει τι κατάφερες!")
    
    # Καταγραφή Προόδου
    try:
        import sys
        sys.path.append("/home/justin/Space_Station_Academy/.pi")
        import tracker
        tracker.update_progress("Mission 4, Μάθημα 25: Dict Methods")
    except Exception:
        pass
except AssertionError as e:
    print("\n🤖 [Pi Agent] Don't be discouraged! Type 'Help' in the side window so we can solve it together!")
    print(f"\n❌ [SYSTEM] Error: {e}")
except Exception as e:
    print("\n🤖 [Pi Agent] Something went wrong with the code. Type 'Help' so we can look at it!")
    print(f"\n❌ [SYSTEM] Error: {e}")

# %% [markdown]
# ### 🎯 Μάθημα 26: Μέγεθος Συλλογών (Η συνάρτηση len())
#
# **Η Ιστορία:** Πώς μπορούμε να μάθουμε πόσα πράγματα έχουμε μέσα σε μια λίστα ή ένα λεξικό; Χρησιμοποιούμε τη συνάρτηση `len()`. Είναι σαν να μετράμε τα αντικείμενα που βάλαμε στα ντουλάπια μας!
#
# **Στόχος:** Υπολόγισε το μέγεθος της λίστας `tools_ekseleysis` χρησιμοποιώντας την `len()` και αποθήκευσέ το στη μεταβλητή `tool_count`. Μετά, εμφάνισε το αποτέλεσμα με print().

# %%
tools_ekseleysis = ["hammer", "wrench", "screwdriver", "rope", "gloves"]

# 💻 Βρες το πλήθος των εργαλείων χρησιμοποιώντας την len() και αποθήκευσέ το στη tool_count:
# tool_count = ...


# === AUTOMATED CHECK ===
try:
    assert 'tool_count' in locals() or 'tool_count' in globals(), "❌ [SYSTEM] Error! Δεν δημιούργησες τη μεταβλητή 'tool_count'!"
    assert tool_count == 5, f"❌ [SYSTEM] Error! Το πλήθος των εργαλείων πρέπει να είναι 5, όχι {tool_count}!"
    print("\n🎉 [SYSTEM] Great job! Μέτρησες σωστά τα εργαλεία με την len()!")
    print("👉 Type 'progress' to the Pi Agent για να δει τι κατάφερες!")
    
    # Καταγραφή Προόδου
    try:
        import sys
        sys.path.append("/home/justin/Space_Station_Academy/.pi")
        import tracker
        tracker.update_progress("Mission 4, Μάθημα 26: Collection Size")
    except Exception:
        pass
except NameError:
    print("\n⚠️ [SYSTEM] Προσοχή! Μήπως έγραψες λάθος το όνομα της μεταβλητής ή ξέχασες να την ορίσεις; Σιγουρέψου ότι γράφεται ακριβώς: tool_count")
except AssertionError as e:
    print("\n🤖 [Pi Agent] Don't be discouraged! Type 'Help' in the side window so we can solve it together!")
    print(f"\n❌ [SYSTEM] Error: {e}")
except Exception as e:
    print("\n🤖 [Pi Agent] Something went wrong with the code. Type 'Help' so we can look at it!")
    print(f"\n❌ [SYSTEM] Error: {e}")

# %% [markdown]
# ## 🎉 Η ΑΠΟΣΤΟΛΗ ΟΛΟΚΛΗΡΩΘΗΚΕ! (Mission Completed)
#
# Μπράβο, **Λεωνίδα**! Οργάνωσες τέλεια τις αποθήκες και τα αρχεία του πληρώματος με Λίστες και Λεξικά!
#
# ### 🚨 Τι πρέπει να κάνεις τώρα:
# 1. Γράψε **`πρόοδος`** στον Pi Agent.
# 2. Γράψε **`/new`** για να ανανεώσεις τον βοηθό σου.
# 3. Click the **NEXT MISSION (NEXT)** button to write your own repair functions!
