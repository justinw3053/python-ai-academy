# %% [markdown]
# # Αποστολή 1Β: 📡 Συστήματα Επικοινωνίας (Input & Casting)
#
# Προχωράμε στο δεύτερο μέρος της ενεργοποίησης! Εδώ θα μάθεις πώς να δίνεις εντολές στο σύστημα και να συνδυάζεις λέξεις με αριθμούς.

# %% [markdown]
# ### 💡 Συμβουλή Ασφαλείας AI (Developer Tip):
#
# Όταν συνομιλείς με τοπικά μοντέλα AI, η μνήμη τους μπορεί να γεμίσει και να αρχίσουν να μπερδεύονται ή να καθυστερούν.
# Για να το αποφύγεις αυτό, είναι **εξαιρετικά σημαντικό** να καθαρίζεις τη μνήμη της AI γράφοντας την εντολή:
# ### `/new`
# στο παράθυρο του **Pi Agent** στο παράθυρο συζήτησης και πατώντας Enter!
#
# **Κάνε το συνήθεια να τρέχεις την `/new` στην αρχή κάθε νέου μαθήματος ή όταν αλλάζεις άσκηση!**

# %% [markdown]
# ### 🎯 Μάθημα 5: Calibration Αισθητήρων (Math Functions)
#
# **Η Ιστορία:** Οι αισθητήρες θερμοκρασίας επιστρέφουν δεκαδικά νούμερα, αλλά χρειαζόμαστε ακέραιες τιμές για να μην μπερδεύεται ο υπολογιστής.
#
# **Στόχος:** Χρησιμοποίησε τη συνάρτηση `round()` για να στρογγυλοποιήσεις τη θερμοκρασία `36.7` και αποθήκευσέ την στη μεταβλητή `thermokrasia_akeraia`.

# %%
thermokrasia = 36.7

# 💻 Στρογγυλοποίησε τη θερμοκρασία χρησιμοποιώντας τη round() και αποθήκευσέ την στη thermokrasia_akeraia:
# thermokrasia_akeraia = ...


# === AUTOMATED CHECK ===
try:
    assert 'thermokrasia_akeraia' in locals() or 'thermokrasia_akeraia' in globals(), "❌ [SYSTEM] Error! Δεν δημιούργησες τη μεταβλητή 'thermokrasia_akeraia'!"
    assert thermokrasia_akeraia == 37, f"❌ [SYSTEM] Error! Η στρογγυλοποίηση δεν είναι σωστή. Η τιμή πρέπει να είναι 37, όχι {thermokrasia_akeraia}!"
    print("\n🎉 [SYSTEM] Great job! Η στρογγυλοποίηση έγινε σωστά και η θερμοκρασία είναι 37!")
    print("👉 Type 'progress' to the Pi Agent για να δει τι κατάφερες!")
    
    # Καταγραφή Προόδου
    try:
        import sys
        sys.path.append("/home/justin/Space_Station_Academy/.pi")
        import tracker
        tracker.update_progress("Mission 1, Μάθημα 5: Calibration")
    except Exception:
        pass
except NameError:
    print("\n⚠️ [SYSTEM] Προσοχή! Μήπως έγραψες λάθος το όνομα της μεταβλητής ή ξέχασες να την ορίσεις; Σιγουρέψου ότι γράφεται ακριβώς: thermokrasia_akeraia")
except AssertionError as e:
    print("\n🤖 [Pi Agent] Don't be discouraged! Type 'Help' in the side window so we can solve it together!")
    print(f"\n❌ [SYSTEM] Error: {e}")
except Exception as e:
    print("\n🤖 [Pi Agent] Something went wrong with the code. Type 'Help' so we can look at it!")
    print(f"\n❌ [SYSTEM] Error: {e}")

# %% [markdown]
# ### 🎯 Μάθημα 6: Είσοδος Χρήστη (input)
#
# **Η Ιστορία:** Το σύστημα ζητάει το δικό σου όνομα για να σου δώσει πρόσβαση μηχανικού.
#
# **Στόχος:** Χρησιμοποίησε την `input()` για να ρωτήσεις το όνομα του χρήστη και αποθήκευσέ το σε μια μεταβλητή. Μετά, χαιρέτησέ τον!

# %%
# 💻 Ρώτησε το όνομα του χρήστη χρησιμοποιώντας την input('Δώσε το όνομά σου: ') 
# και αποθήκευσέ το στη μεταβλητή onoma_xristi. Μετά εμφάνισε ένα χαιρετισμό:


# === AUTOMATED CHECK ===
try:
    assert 'onoma_xristi' in locals() or 'onoma_xristi' in globals(), "❌ [SYSTEM] Error! Δεν δημιούργησες τη μεταβλητή 'onoma_xristi'!"
    print(f"\n🎉 [SYSTEM] Great job! Καλώς όρισες, {onoma_xristi}!")
    print("👉 Type 'progress' to the Pi Agent για να δει τι κατάφερες!")
    
    try:
        import sys
        sys.path.append("/home/justin/Space_Station_Academy/.pi")
        import tracker
        tracker.update_progress("Mission 1, Μάθημα 6: User Input")
    except Exception:
        pass
except NameError:
    print("\n⚠️ [SYSTEM] Προσοχή! Μήπως έγραψες λάθος το όνομα της μεταβλητής ή ξέχασες να την ορίσεις; Σιγουρέψου ότι γράφεται ακριβώς: onoma_xristi")
except AssertionError as e:
    print("\n🤖 [Pi Agent] Don't be discouraged! Type 'Help' in the side window so we can solve it together!")
    print(f"\n❌ [SYSTEM] Error: {e}")
except Exception as e:
    print("\n🤖 [Pi Agent] Something went wrong with the code. Type 'Help' so we can look at it!")
    print(f"\n❌ [SYSTEM] Error: {e}")

# %% [markdown]
# ### 🎯 Μάθημα 7: f-strings
#
# **Η Ιστορία:** Θέλουμε να εμφανίσουμε ένα όμορφο μήνυμα που να συνδυάζει κείμενο και μεταβλητές εύκολα.
#
# **Στόχος:** Χρησιμοποίησε ένα f-string (f'...') για να εμφανίσεις το όνομα και την ηλικία του αστροναύτη και αποθήκευσέ το στη μεταβλητή `minyma`.

# %%
onoma = "Γιάννης"
ilikia = 12

# 💻 Συμπλήρωσε το f-string από κάτω για να εμφανίσεις: 'Ο αστροναύτης Γιάννης είναι 12 ετών.'
# minyma = f"..."


# === AUTOMATED CHECK ===
try:
    assert 'minyma' in locals() or 'minyma' in globals(), "❌ [SYSTEM] Error! Δεν δημιούργησες τη μεταβλητή 'minyma'!"
    # Forgiving check: clean up punctuation and ignore casing
    student_clean = str(minyma).strip().replace(".", "").replace("!", "").replace(" ", "").lower()
    target_clean = "Ο αστροναύτης Γιάννης είναι 12 ετών.".strip().replace(".", "").replace("!", "").replace(" ", "").lower()
    assert student_clean == target_clean or ("αστροναύτης" in student_clean and "γιάννης" in student_clean and "12" in student_clean), f"❌ [SYSTEM] Error! Το f-string δεν περιέχει το όνομα ή την ηλικία ή το μήνυμα σωστά!"
    print("\n🎉 [SYSTEM] Great job! Το f-string συνδυάστηκε τέλεια!")
    print(f"Μήνυμα: {minyma}")
    print("👉 Type 'progress' to the Pi Agent για να δει τι κατάφερες!")
    
    # Καταγραφή Προόδου
    try:
        import sys
        sys.path.append("/home/justin/Space_Station_Academy/.pi")
        import tracker
        tracker.update_progress("Mission 1, Μάθημα 7: f-strings")
    except Exception:
        pass
except NameError:
    print("\n⚠️ [SYSTEM] Προσοχή! Μήπως έγραψες λάθος το όνομα της μεταβλητής ή ξέχασες να την ορίσεις; Σιγουρέψου ότι γράφεται ακριβώς: minyma")
except AssertionError as e:
    print("\n🤖 [Pi Agent] Don't be discouraged! Type 'Help' in the side window so we can solve it together!")
    print(f"\n❌ [SYSTEM] Error: {e}")
except Exception as e:
    print("\n🤖 [Pi Agent] Something went wrong with the code. Type 'Help' so we can look at it!")
    print(f"\n❌ [SYSTEM] Error: {e}")

# %% [markdown]
# ### 🎯 Μάθημα 8: Μετατροπή Τύπων (Type Casting)
#
# **Η Ιστορία:** Όταν παίρνουμε νούμερα από τον χρήστη με την `input()`, το Python τα βλέπει σαν απλό κείμενο. Πρέπει να τα μετατρέψουμε σε αριθμούς για να κάνουμε μαθηματικά!
#
# **Στόχος:** Πάρε έναν αριθμό από τον χρήστη, μετέτρεψέ τον σε ακέραιο με την `int()`, πρόσθεσε 10 και αποθήκευσε το αποτέλεσμα στη μεταβλητή `teliko_noumero`.

# %%
noumero_keimeno = input("Δώσε έναν αριθμό: ")

# 💻 Μετέτρεψε το noumero_keimeno σε ακέραιο χρησιμοποιώντας την int(), 
# πρόσθεσε 10 και αποθήκευσε το αποτέλεσμα στη μεταβλητή teliko_noumero:
# teliko_noumero = ...


# === AUTOMATED CHECK ===
try:
    assert 'teliko_noumero' in locals() or 'teliko_noumero' in globals(), "❌ [SYSTEM] Error! Δεν δημιούργησες τη μεταβλητή 'teliko_noumero'!"
    assert isinstance(teliko_noumero, int), f"❌ [SYSTEM] Error! Το αποτέλεσμα πρέπει να είναι ακέραιος (int), όχι {type(teliko_noumero)}! Χρησιμοποίησες την int() ;"
    print(f"\n🎉 [SYSTEM] Great job! Μετέτρεψες το κείμενο σε αριθμό με επιτυχία! Αποτέλεσμα: {teliko_noumero}")
    print("👉 Type 'progress' to the Pi Agent για να δει τι κατάφερες!")
    
    # Καταγραφή Προόδου
    try:
        import sys
        sys.path.append("/home/justin/Space_Station_Academy/.pi")
        import tracker
        tracker.update_progress("Mission 1, Μάθημα 8: Type Casting")
    except Exception:
        pass
except NameError:
    print("\n⚠️ [SYSTEM] Προσοχή! Μήπως έγραψες λάθος το όνομα της μεταβλητής ή ξέχασες να την ορίσεις; Σιγουρέψου ότι γράφεται ακριβώς: teliko_noumero")
except AssertionError as e:
    print("\n🤖 [Pi Agent] Don't be discouraged! Type 'Help' in the side window so we can solve it together!")
    print(f"\n❌ [SYSTEM] Error: {e}")
except Exception as e:
    print("\n🤖 [Pi Agent] Something went wrong with the code. Type 'Help' so we can look at it!")
    print(f"\n❌ [SYSTEM] Error: {e}")

# %% [markdown]
# ## 🎉 Η ΑΠΟΣΤΟΛΗ ΟΛΟΚΛΗΡΩΘΗΚΕ! (Mission Completed)
#
# Μπράβο, **Λεωνίδα**! Ενεργοποίησες πλήρως την κονσόλα και τους αισθητήρες του σταθμού Aether!
#
# ### 🚨 Τι πρέπει να κάνεις τώρα:
# 1. Σιγουρέψου ότι έγραψες **`πρόοδος`** στον Pi Agent για να καταγράψει την επιτυχία σου.
# 2. Γράψε την εντολή **`/new`** στον Pi Agent για να καθαρίσεις τη μνήμη του.
# 3. Κάνε κλικ στο κουμπί **ΕΠΟΜΕΝΟ ΜΑΘΗΜΑ (NEXT)** για να μάθεις πώς να παίρνεις αποφάσεις λογικής!
