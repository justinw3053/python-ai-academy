# %% [markdown]
# # Αποστολή 5: 🛠️ Μηχανικός Πυρήνας (Functions)
#
# Ώρα να γίνεις πραγματικός Μηχανικός! Σε αυτό το τετράδιο θα μάθεις πώς να γράφεις τις δικές σου συναρτήσεις (Functions) για να δημιουργείς επαναχρησιμοποιήσιμα προγράμματα και μακροεντολές επισκευής.

# %% [markdown]
# ### 🎯 Μάθημα 27: Ορισμός Συναρτήσεων (def)
#
# **Η Ιστορία:** Μια συνάρτηση (function) είναι σαν ένα έτοιμο πακέτο κώδικα που του δίνουμε ένα όνομα και μπορούμε να το χρησιμοποιούμε όποτε θέλουμε χωρίς να το ξαναγράφουμε!
#
# **Στόχος:** Φτιάξε μια συνάρτηση με όνομα `start_engines` που εμφανίζει `'Κινητήρες έτοιμοι!'`.

# %%
# 💻 Όρισε τη συνάρτηση start_engines χρησιμοποιώντας def:


# === AUTOMATED CHECK ===
try:
    assert 'start_engines' in locals(), "❌ [SYSTEM] Error! Δεν όρισες τη συνάρτηση 'start_engines'!"
    assert callable(start_engines), "❌ [SYSTEM] Error! Το 'start_engines' πρέπει να είναι συνάρτηση!"
    print("\n🎉 [SYSTEM] Great job! Η συνάρτηση 'start_engines' ορίστηκε με επιτυχία!")
    print("Εκτέλεση συνάρτησης:")
    start_engines()
    print("👉 Type 'progress' to the Pi Agent για να δει τι κατάφερες!")
    
    # Καταγραφή Προόδου
    try:
        import sys
        sys.path.append("/opt/space-station-academy/.pi")
        import tracker
        tracker.update_progress("Mission 5, Μάθημα 27: Defining Functions")
    except Exception:
        pass
except AssertionError as e:
    print("\n🤖 [Pi Agent] Don't be discouraged! Type 'Help' in the side window so we can solve it together!")
    print(f"\n❌ [SYSTEM] Error: {e}")
except Exception as e:
    print("\n🤖 [Pi Agent] Something went wrong with the code. Type 'Help' so we can look at it!")
    print(f"\n❌ [SYSTEM] Error: {e}")

# %% [markdown]
# ### 🎯 Μάθημα 28: Κλήση Συναρτήσεων
#
# **Η Ιστορία:** Για να τρέξει ο κώδικας μιας συνάρτησης, πρέπει να την καλέσουμε γράφοντας το όνομά της με παρενθέσεις.
#
# **Στόχος:** Κάλεσε τη συνάρτηση `check_radar` 3 φορές στη σειρά.

# %%
def check_radar():
    print("Σάρωση τομέα...")

# 💻 Κάλεσε τη συνάρτηση 3 φορές από κάτω:

# %% [markdown]
# ### 🎯 Μάθημα 29: Παράμετροι & Ορίσματα
#
# **Η Ιστορία:** Μπορούμε να στείλουμε πληροφορίες (arguments) μέσα σε μια συνάρτηση για να αλλάξουμε τη συμπεριφορά της.
#
# **Στόχος:** Φτιάξε μια συνάρτηση `set_power(pososto)` που εμφανίζει `'Ισχύς στο '` μαζί με το ποσοστό.

# %%
# 💻 Φτιάξε τη συνάρτηση με παράμετρο pososto και κάλεσε την με την τιμή 75:


# === AUTOMATED CHECK ===
try:
    assert 'set_power' in locals(), "❌ [SYSTEM] Error! Δεν όρισες τη συνάρτηση 'set_power'!"
    assert callable(set_power), "❌ [SYSTEM] Error! Το 'set_power' πρέπει να είναι συνάρτηση!"
    import inspect
    sig = inspect.signature(set_power)
    assert 'pososto' in sig.parameters, "❌ [SYSTEM] Error! Η συνάρτηση set_power πρέπει να δέχεται την παράμετρο 'pososto'!"
    print("\n🎉 [SYSTEM] Great job! Η συνάρτηση 'set_power' ορίστηκε σωστά!")
    print("Εκτέλεση με τιμή 90:")
    set_power(90)
    print("👉 Type 'progress' to the Pi Agent για να δει τι κατάφερες!")
    
    # Καταγραφή Προόδου
    try:
        import sys
        sys.path.append("/opt/space-station-academy/.pi")
        import tracker
        tracker.update_progress("Mission 5, Μάθημα 29: Parameters")
    except Exception:
        pass
except AssertionError as e:
    print("\n🤖 [Pi Agent] Don't be discouraged! Type 'Help' in the side window so we can solve it together!")
    print(f"\n❌ [SYSTEM] Error: {e}")
except Exception as e:
    print("\n🤖 [Pi Agent] Something went wrong with the code. Type 'Help' so we can look at it!")
    print(f"\n❌ [SYSTEM] Error: {e}")

# %% [markdown]
# ### 🎯 Μάθημα 30: Επιστροφή Τιμών (return)
#
# **Η Ιστορία:** Μια συνάρτηση μπορεί να υπολογίσει κάτι και να μας επιστρέψει το αποτέλεσμα χρησιμοποιώντας τη λέξη `return`.
#
# **Στόχος:** Φτιάξε μια συνάρτηση `add_boost(energy)` που επιστρέφει την ενέργεια αυξημένη κατά 50.

# %%
# 💻 Όρισε τη συνάρτηση add_boost(energy) που κάνει return την ενέργεια αυξημένη κατά 50 


# === AUTOMATED CHECK ===
try:
    assert 'add_boost' in locals(), "❌ [SYSTEM] Error! Δεν όρισες τη συνάρτηση 'add_boost'!"
    assert add_boost(100) == 150, f"❌ [SYSTEM] Error! Η συνάρτηση add_boost(100) πρέπει να επιστρέφει 150, όχι {add_boost(100)}!"
    print("\n🎉 [SYSTEM] Great job! Η συνάρτηση 'add_boost' επιστρέφει σωστά την αυξημένη ενέργεια!")
    print("👉 Type 'progress' to the Pi Agent για να δει τι κατάφερες!")
    
    # Καταγραφή Προόδου
    try:
        import sys
        sys.path.append("/opt/space-station-academy/.pi")
        import tracker
        tracker.update_progress("Mission 5, Μάθημα 30: Return Values")
    except Exception:
        pass
except AssertionError as e:
    print("\n🤖 [Pi Agent] Don't be discouraged! Type 'Help' in the side window so we can solve it together!")
    print(f"\n❌ [SYSTEM] Error: {e}")
except Exception as e:
    print("\n🤖 [Pi Agent] Something went wrong with the code. Type 'Help' so we can look at it!")
    print(f"\n❌ [SYSTEM] Error: {e}")

# %% [markdown]
# ### 🎯 Μάθημα 31: Συνδυαστική Άσκηση Συναρτήσεων (Functions Challenge)
#
# **Η Ιστορία:** Ώρα για την τελική δοκιμασία του Μηχανικού Πυρήνα! Πρέπει να φτιάξεις μια συνάρτηση που δέχεται μια λίστα με επίπεδα ενέργειας, υπολογίζει το σύνολό τους χρησιμοποιώντας μια λούπα, και επιστρέφει το αποτέλεσμα. Αυτό συνδυάζει όλα όσα έμαθες για τις Λίστες, τις Λούπες, και τις Συναρτήσεις!
#
# **Στόχος:** Φτιάξε μια συνάρτηση με όνομα `calculate_total_power(power_list)` που παίρνει μια λίστα από αριθμούς, χρησιμοποιεί μια λούπα `for` για να τους προσθέσει όλους, και επιστρέφει το συνολικό άθροισμα με την εντολή `return`.

# %%
# 💻 Φτιάξε τη συνάρτηση calculate_total_power(power_list) από κάτω:
# def calculate_total_power(power_list):
#     synolo = 0
#     for power in power_list:
#         ...
#     return ...


# === AUTOMATED CHECK ===
try:
    assert 'calculate_total_power' in locals() or 'calculate_total_power' in globals(), "❌ [SYSTEM] Error! Δεν όρισες τη συνάρτηση 'calculate_total_power'!"
    assert callable(calculate_total_power), "❌ [SYSTEM] Error! Το 'calculate_total_power' πρέπει να είναι συνάρτηση!"
    
    test_list = [100, 200, 150]
    result = calculate_total_power(test_list)
    assert result == 450, f"❌ [SYSTEM] Error! Για τη λίστα [100, 200, 150] η συνάρτηση επέστρεψε {result} αντί για 450!"
    
    print("\n🎉 [SYSTEM] Great job! Η συνάρτηση 'calculate_total_power' λειτουργεί τέλεια και υπολογίζει σωστά το σύνολο!")
    print("👉 Type 'progress' to the Pi Agent για να δει τι κατάφερες!")
    
    # Καταγραφή Προόδου
    try:
        import sys
        sys.path.append("/opt/space-station-academy/.pi")
        import tracker
        tracker.update_progress("Mission 5, Μάθημα 31: Functions Challenge")
    except Exception:
        pass
except NameError:
    print("\n⚠️ [SYSTEM] Προσοχή! Μήπως έγραψες λάθος το όνομα της συνάρτησης ή ξέχασες να την ορίσεις; Σιγουρέψου ότι γράφεται ακριβώς: calculate_total_power")
except AssertionError as e:
    print("\n🤖 [Pi Agent] Don't be discouraged! Type 'Help' in the side window so we can solve it together!")
    print(f"\n❌ [SYSTEM] Error: {e}")
except Exception as e:
    print("\n🤖 [Pi Agent] Something went wrong with the code. Type 'Help' so we can look at it!")
    print(f"\n❌ [SYSTEM] Error: {e}")

# %% [markdown]
# ## 🎉 Η ΑΠΟΣΤΟΛΗ ΟΛΟΚΛΗΡΩΘΗΚΕ! (Mission Completed)
#
# Είσαι πλέον ένας αληθινός Μηχανικός, **Λεωνίδα**! Οι δικές σου συναρτήσεις (Functions) είναι έτοιμες να εκτελέσουν αυτόματες επισκευές!
#
# ### 🚨 Τι πρέπει να κάνεις τώρα:
# 1. Γράψε **`πρόοδος`** στον Pi Agent.
# 2. Γράψε **`/new`** για να κρατήσεις την AI γρήγορη.
# 3. Κάνε κλικ στο κουμπί **ΕΠΟΜΕΝΟ ΜΑΘΗΜΑ (NEXT)** για να μάθεις πώς να εισάγεις έτοιμες βιβλιοθήκες, να χειρίζεσαι αρχεία και να προστατεύεις το σύστημα από κρασαρίσματα!
