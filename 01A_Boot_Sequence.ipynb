# %% [markdown]
# # 🚀 Ακαδημία Διαστήματος: Επιχείρηση Override
#
# Καλώς όρισες, **Λεωνίδα**, στον Διαστημικό Σταθμό "Aether"!
#
# Ο σταθμός έχει υποστεί σοβαρή βλάβη στα συστήματά του μετά από μια καταιγίδα μετεωριτών. Η κεντρική Τεχνητή Νοημοσύνη (Security AI) έχει κλειδωθεί σε "Σωκρατική Λειτουργία Ασφαλείας" και αρνείται να μας δώσει τον κωδικό επανεκκίνησης του αντιδραστήρα.
#
# **Η Αποστολή σου:**
# Να μάθεις Python και να αναπτύξεις τις ικανότητές σου στην Τεχνητή Νοημοσύνη, ώστε να επισκευάσεις ένα-προς-ένα τα συστήματα του σταθμού. Στο τέλος, θα πρέπει να γράψεις ένα πρόγραμμα που θα παρακάμψει την ασφάλεια της AI και θα πάρει τον κωδικό επανεκκίνησης!
#
# ---
#
# ## 🛑 ΟΔΗΓΙΕΣ ΑΠΟΣΤΟΛΗΣ (Διάβασε πριν ξεκινήσεις!)
#
# Πριν πατήσεις το πρώτο κουμπί, ακολούθησε αυτά τα **βήματα** για να ενεργοποιήσεις τα συστήματα του σταθμού:
#
# ### 1️⃣ Βήμα 1: Ξύπνησε τον Ψηφιακό σου Δάσκαλο (Pi Agent)!
# * Κάνε κλικ στο **δεξί μαύρο παράθυρο** (τερματικό), πληκτρολόγησε τη λέξη:
#   ### `pi`
#   και πάτα **Enter**!
# * Ο προσωπικός σου Socratic δάσκαλος θα ξυπνήσει. Μπορείς να του γράφεις τις ερωτήσεις σου στα Ελληνικά όταν δυσκολεύεσαι!
#
# ### 2️⃣ Βήμα 2: Γράψε Κώδικα και πάτα το Play!
# * Σε κάθε μάθημα θα βρεις γκρίζα κουτάκια κώδικα. Συμπλήρωσε τον κώδικα που λείπει.
# * Πάτα το κουμπί **Play** ▶️ (στα αριστερά του κουτιού, ή `Ctrl+Enter`) για να τρέξεις το πρόγραμμα και να ελέγξεις αν είναι σωστός!
#
# ### 3️⃣ Βήμα 3: Ενημέρωσε τον δάσκαλό σου με τη λέξη `πρόοδος`!
# * Μόλις πάρεις πράσινο τσεκάρισμα επιτυχίας σε μια άσκηση, γράψε τη λέξη:
#   ### `πρόοδος`
#   στο δεξί παράθυρο του Pi Agent και πάτα Enter! Θα διαβάσει τη μνήμη σου και θα σε συγχαρεί!
#
# ### 4️⃣ Βήμα 4: Καθάρισε τη Μνήμη της AI (`/new`)
# * 💡 *AI Tip: Αν ο Pi Agent αρχίσει να καθυστερεί ή να μπερδεύεται επειδή γεμίζει η μνήμη του, γράψε του τη λέξη:*
#   ### `/new`
#   *για να καθαρίσεις τη μνήμη του και να ξαναγίνει ταχύτατος! Κάνε το συνήθεια στην αρχή κάθε μαθήματος.*
#
# ---
#
# ## 🔧 Τι να κάνεις αν δυσκολευτείς με τον Υπολογιστή:
# * **Αν σου ζητήσει "Select Kernel" ή "Επιλογή Kernel" (πάνω δεξιά):** Κάνε κλικ εκεί, διάλεξε **'Python Environments...'** και μετά διάλεξε την έκδοση της Python που σου προτείνει (π.χ. 'Python 3.x').
# * **Αν σου ζητήσει εγκατάσταση 'Python' / 'Jupyter' extension:** Πάτα το κουμπί **Install (Εγκατάσταση)** και περίμενε μερικά δευτερόλεπτα!
# * **Αν κολλήσει ο κώδικας και δεν τρέχει τίποτα:** Πάτα το κυκλικό βελάκι **Restart (Επανεκκίνηση)** στο πάνω μέρος του παραθύρου.
# * **Αν δεις ένα τρομακτικό κόκκινο μήνυμα λάθους στα Αγγλικά (π.χ. SyntaxError):** Μην πανικοβάλλεσαι! Κάνε αντιγραφή-επικόλληση όλο το κόκκινο μήνυμα στον Pi Agent (δεξιά) και ρώτησέ τον τι σημαίνει!
#
# ---
# 🌌 **Ο σταθμός Aether βασίζεται πάνω σου, Λεωνίδα! Καλή σου επιτυχία!**

# %% [markdown]
# # Workbook 1: 🚀 Ενεργοποίηση & Πυρήνες Δεδομένων
#
# Καλώς όρισες στο πρώτο σου διαδραστικό τετράδιο εργασίας (Jupyter Workbook)!
#
# Εδώ θα μάθεις τις βασικές αρχές της Python (Εκτύπωση, Μεταβλητές, Αριθμοί, και Είσοδος Χρήστη) για να ενεργοποιήσεις την κονσόλα και τους αισθητήρες του Διαστημικού Σταθμού Aether.

# %% [markdown]
# ### 💡 Συμβουλή Ασφαλείας AI (Developer Tip):
#
# Όταν συνομιλείς με τοπικά μοντέλα AI, η μνήμη τους μπορεί να γεμίσει και να αρχίσουν να μπερδεύονται ή να καθυστερούν.
# Για να το αποφύγεις αυτό, είναι **εξαιρετικά σημαντικό** να καθαρίζεις τη μνήμη της AI γράφοντας την εντολή:
# ### `/new`
# στο παράθυρο του **Pi Agent** στο δεξί τερματικό και πατώντας Enter!
#
# **Κάνε το συνήθεια να τρέχεις την `/new` στην αρχή κάθε νέου μαθήματος ή όταν αλλάζεις άσκηση!**

# %% [markdown]
# ### 🎯 Μάθημα 1: Η Αρχική Εκκίνηση (print)
#
# **Η Ιστορία:** Η οθόνη του υπολογιστή σου είναι σκοτεινή. Πρέπει να στείλεις ένα σήμα για να δείξεις ότι είσαι ζωντανός!
#
# **Στόχος:** Χρησιμοποίησε την εντολή `print()` για να εμφανίσεις το μήνυμα `'ΣΥΣΤΗΜΑ ΕΝΕΡΓΟΠΟΙΗΘΗΚΕ'`.

# %%
# 💻 Γράψε την εντολή print() από κάτω για να στείλεις το σήμα:
# (Συμβουλή: Πληκτρολόγησε: print("ΣΥΣΤΗΜΑ ΕΝΕΡΓΟΠΟΙΗΘΗΚΕ") )
# Out:
# ΣΥΣΤΗΜΑ ΕΝΕΡΓΟΠΟΙΗΘΗΚΕ

# %% [markdown]
# ### 🎯 Μάθημα 2: Μηνύματα Καλωσορίσματος
#
# **Η Ιστορία:** Η κονσόλα ζητάει ένα όμορφο μήνυμα καλωσορίσματος για το πλήρωμα.
#
# **Στόχος:** Εμφάνισε τρεις γραμμές κειμένου που καλωσορίζουν το πλήρωμα στον σταθμό.

# %%
# 💻 Εμφάνισε 3 γραμμές με μηνύματα καλωσορίσματος χρησιμοποιώντας το print()
# Out:
# hello guys
# how are you doing
# what do you need

# %% [markdown]
# ### 🎯 Μάθημα 3: Αποθήκευση στη Μνήμη (Variables)
#
# **Η Ιστορία:** Πρέπει να αποθηκεύσεις το όνομα του διαστημοπλοίου σε ένα 'ντουλαπάκι' (μεταβλητή) για να το θυμάται το σύστημα.
#
# **Στόχος:** Φτιάξε μια μεταβλητή με όνομα `onoma_skafous` και δώσε της την τιμή `'Aether'`. Μετά εμφάνισέ την.

# %%
# 💻 Φτιάξε τη μεταβλητή onoma_skafous εδώ:
# onoma_skafous = ...

# 💻 Εμφάνισέ την με print() από κάτω:


# === AUTOMATED CHECK ===
try:
    assert 'onoma_skafous' in locals() or 'onoma_skafous' in globals(), "❌ [SYSTEM] Error! Δεν δημιούργησες τη μεταβλητή με όνομα 'onoma_skafous'!"
    # Forgiving check: clean up whitespaces and ignore casing
    current_val = str(onoma_skafous).strip().lower()
    assert current_val == "aether", f"❌ [SYSTEM] Error! Η μεταβλητή 'onoma_skafous' πρέπει να έχει την τιμή 'Aether', όχι '{onoma_skafous}'!"
    print("\n🎉 [SYSTEM] Great job! Η μεταβλητή 'onoma_skafous' αποθηκεύτηκε σωστά ως 'Aether'!")
    print("👉 Type 'progress' to the Pi Agent για να δει τι κατάφερες!")
    
    # Καταγραφή Προόδου
    try:
        import sys
        sys.path.append("/home/justin/Space_Station_Academy/.pi")
        import tracker
        tracker.update_progress("Workbook 1, Μάθημα 3: Variables")
    except Exception:
        pass
except NameError:
    print("\n🤖 [Pi Agent] Αν κόλλησες, γράψε μου 'Βοήθεια με το Μάθημα 3' στο διπλανό παράθυρο!")
    print("\n⚠️ [SYSTEM] Προσοχή! Μήπως έγραψες λάθος το όνομα της μεταβλητής ή ξέχασες να την ορίσεις; Σιγουρέψου ότι γράφεται ακριβώς: onoma_skafous")
except AssertionError as e:
    print(f"\n❌ [SYSTEM] Error: {e}")
except Exception as e:
    print("\n🤖 [Pi Agent] Αν δεν ξέρεις πώς να το λύσεις, γράψε μου 'Βοήθεια με το Μάθημα 3'!")
    print(f"\n❌ [SYSTEM] Error: {e}")

# %% [markdown]
# ### 🎯 Μάθημα 4: Υπολογισμός Ενέργειας (Numbers)
#
# **Η Ιστορία:** Ο αντιδραστήρας χρειάζεται υπολογισμό της ενέργειας. Έχουμε 5 μπαταρίες, και η καθεμία έχει 120 μονάδες ενέργειας.
#
# **Στόχος:** Υπολόγισε τη συνολική ενέργεια πολλαπλασιάζοντας τις μπαταρίες, αποθήκευσέ την στη μεταβλητή `synoliki_energeia` και εμφάνισε το αποτέλεσμα.

# %%
mpataries = 5
energeia_ana_mpataria = 120

# 💻 Υπολόγισε τη συνολική ενέργεια και αποθήκευσέ την στη μεταβλητή synoliki_energeia:
# synoliki_energeia = ...


# === AUTOMATED CHECK ===
try:
    assert 'synoliki_energeia' in locals() or 'synoliki_energeia' in globals(), "❌ [SYSTEM] Error! Δεν δημιούργησες τη μεταβλητή με όνομα 'synoliki_energeia'!"
    assert synoliki_energeia == 600, f"❌ [SYSTEM] Error! Ο υπολογισμός είναι εσφαλμένος. Το αποτέλεσμα πρέπει να είναι 600, όχι {synoliki_energeia}!"
    print("\n🎉 [SYSTEM] Great job! Η συνολική ενέργεια υπολογίστηκε σωστά στα 600!")
    print("👉 Type 'progress' to the Pi Agent για να δει τι κατάφερες!")
    
    # Καταγραφή Προόδου
    try:
        import sys
        sys.path.append("/home/justin/Space_Station_Academy/.pi")
        import tracker
        tracker.update_progress("Workbook 1, Μάθημα 4: Numbers")
    except Exception:
        pass
except NameError:
    print("\n⚠️ [SYSTEM] Προσοχή! Μήπως έγραψες λάθος το όνομα της μεταβλητής ή ξέχασες να την ορίσεις; Σιγουρέψου ότι γράφεται ακριβώς: synoliki_energeia")
except AssertionError as e:
    print("\n🤖 [Pi Agent] Αν μπερδεύτηκες με τα νούμερα, γράψε μου 'Βοήθεια με το Μάθημα 4'!")
    print(f"\n❌ [SYSTEM] Error: {e}")
except Exception as e:
    print("\n🤖 [Pi Agent] Μην ανησυχείς! Γράψε μου 'Βοήθεια με το Μάθημα 4' στο τερματικό!")
    print(f"\n❌ [SYSTEM] Error: {e}")

# %% [markdown]
# ## 🎉 ΠΡΩΤΟ ΣΤΑΔΙΟ ΟΛΟΚΛΗΡΩΘΗΚΕ!
#
# Μπράβο, **Λεωνίδα**! Οι βασικοί πυρήνες είναι online.
#
# ### 🚨 Τι πρέπει να κάνεις τώρα:
# 1. Γράψε **`πρόοδος`** στον Pi Agent.
# 2. Γράψε **`/new`** για να καθαρίσεις τη μνήμη του.
# 3. Κλείσε αυτό το τετράδιο και άνοιξε το **`01B_Comms_Systems.ipynb`** για να μάθεις πώς να επικοινωνείς με τον σταθμό!
