# %% [markdown]
# # Workbook 1B: 📡 Communications Systems (Input & Casting)
#
# We are advancing to the second part of the boot sequence! Here, you'll learn how to issue commands to the system and combine words with numbers.

# %% [markdown]
# ### 💡 Developer Safety Tip:
#
# When chatting with local AI models, their context window (memory) can fill up, causing them to hallucinate or slow down.
# To prevent this, it is **extremely important** that you wipe the AI's memory by typing the command:
# ### `/new`
# into the **Pi Agent's** terminal window and pressing Enter!
#
# **Make it a habit to run `/new` at the beginning of each new lesson or whenever you switch exercises!**

# %% [markdown]
# ### 🎯 Lesson 5: Sensor Calibration (Math Functions)
#
# **The Story:** The temperature sensors are returning decimals, but the main computer needs whole numbers to process them without crashing.
#
# **Objective:** Use the `round()` function to round the temperature `36.7` and save it to the variable `rounded_temp`.

# %%
temperature = 36.7

# 💻 Round the temperature using round() and save it to rounded_temp:
# rounded_temp = ___


# === AUTOMATED CHECK ===
try:
    import inspect
    cell_code = inspect.getsource(inspect.currentframe())
    student_code = cell_code.split('# ===')[0].strip()
    assert len([l for l in student_code.split('\n') if not l.strip().startswith('#') and l.strip()]) > 1, "You didn't write any code!"
    assert '___' not in student_code, "Fill in the blanks!"
    assert 'rounded_temp' in locals() or 'rounded_temp' in globals(), "❌ [SYSTEM] Error! You didn't create the 'rounded_temp' variable!"
    assert rounded_temp == 37, f"❌ [SYSTEM] Error! The rounding is incorrect. The value should be 37, not {rounded_temp}!"
    print("\n🎉 [SYSTEM] Great job! Calibration successful. The temperature is now exactly 37!")
    print("👉 Type 'progress' to the Pi Agent to log your achievement!")
    try:
        import sys
        sys.path.append("/home/justin/Space_Station_Academy/.pi")
        import tracker
        tracker.update_progress("Workbook 1, Lesson 5: Calibration")
    except Exception:
        pass
except NameError:
    print("\n⚠️ [SYSTEM] Warning! Did you misspell the variable name? Make sure it is exactly: rounded_temp")
except AssertionError as e:
    print("\n🤖 [Pi Agent] Don't be discouraged! Type 'Help' in the side window so we can solve it together!")
    print(f"\n❌ [SYSTEM] Error: {e}")
except Exception as e:
    print("\n🤖 [Pi Agent] Something went wrong with the code. Type 'Help' so we can look at it!")
    print(f"\n❌ [SYSTEM] Error: {e}")

# %% [markdown]
# ### 🎯 Lesson 6: User Input (input)
#
# **The Story:** The system is requesting your name to grant you Chief Engineer access.
#
# **Objective:** Use `input()` to ask for the user's name and save it to a variable. Then, greet them!

# %%
# 💻 Ask for the user's name using input('Enter your name: ') 
# and save it to the variable user_name. Then display a greeting:


# === AUTOMATED CHECK ===
try:
    import inspect
    cell_code = inspect.getsource(inspect.currentframe())
    student_code = cell_code.split('# ===')[0].strip()
    assert len([l for l in student_code.split('\n') if not l.strip().startswith('#') and l.strip()]) > 1, "You didn't write any code!"
    assert '___' not in student_code, "Fill in the blanks!"
    assert 'user_name' in locals() or 'user_name' in globals(), "❌ [SYSTEM] Error! You didn't create the 'user_name' variable!"
    print(f"\n🎉 [SYSTEM] Great job! Welcome aboard, {user_name}!")
    print("👉 Type 'progress' to the Pi Agent to log your achievement!")
    try:
        import sys
        sys.path.append("/home/justin/Space_Station_Academy/.pi")
        import tracker
        tracker.update_progress("Workbook 1, Lesson 6: User Input")
    except Exception:
        pass
except NameError:
    print("\n⚠️ [SYSTEM] Warning! Did you misspell the variable name? Make sure it is exactly: user_name")
except AssertionError as e:
    print("\n🤖 [Pi Agent] Don't be discouraged! Type 'Help' in the side window so we can solve it together!")
    print(f"\n❌ [SYSTEM] Error: {e}")
except Exception as e:
    print("\n🤖 [Pi Agent] Something went wrong with the code. Type 'Help' so we can look at it!")
    print(f"\n❌ [SYSTEM] Error: {e}")

# %% [markdown]
# ### 🎯 Lesson 7: The Magic of f-strings
#
# **The Story:** We want to broadcast a clean, formatted message across the station that easily combines text and variables.
#
# **Objective:** Use an f-string (`f'...'`) to display the astronaut's name and age, and save it to the variable `message`.

# %%
name = "John"
age = 12

# 💻 Complete the f-string below to display: 'Astronaut John is 12 years old.'
# message = f"___"


# === AUTOMATED CHECK ===
try:
    import inspect
    cell_code = inspect.getsource(inspect.currentframe())
    student_code = cell_code.split('# ===')[0].strip()
    assert len([l for l in student_code.split('\n') if not l.strip().startswith('#') and l.strip()]) > 1, "You didn't write any code!"
    assert '___' not in student_code, "Fill in the blanks!"
    assert 'message' in locals() or 'message' in globals(), "❌ [SYSTEM] Error! You didn't create the 'message' variable!"
    student_clean = str(message).strip().replace(".", "").replace("!", "").replace(" ", "").lower()
    target_clean = "Astronaut John is 12 years old.".strip().replace(".", "").replace("!", "").replace(" ", "").lower()
    assert student_clean == target_clean or ("astronaut" in student_clean and "john" in student_clean and "12" in student_clean), f"❌ [SYSTEM] Error! The f-string doesn't properly format the message!"
    print("\n🎉 [SYSTEM] Great job! The f-string was perfectly crafted!")
    print(f"Broadcast: {message}")
    print("👉 Type 'progress' to the Pi Agent to log your achievement!")
    try:
        import sys
        sys.path.append("/home/justin/Space_Station_Academy/.pi")
        import tracker
        tracker.update_progress("Workbook 1, Lesson 7: f-strings")
    except Exception:
        pass
except NameError:
    print("\n⚠️ [SYSTEM] Warning! Did you misspell the variable name? Make sure it is exactly: message")
except AssertionError as e:
    print("\n🤖 [Pi Agent] Don't be discouraged! Type 'Help' in the side window so we can solve it together!")
    print(f"\n❌ [SYSTEM] Error: {e}")
except Exception as e:
    print("\n🤖 [Pi Agent] Something went wrong with the code. Type 'Help' so we can look at it!")
    print(f"\n❌ [SYSTEM] Error: {e}")

# %% [markdown]
# ### 🎯 Lesson 8: Type Casting
#
# **The Story:** When we capture numbers from the user via `input()`, Python sees them as plain text. We must convert them into real numbers before we can do math!
#
# **Objective:** Grab a number from the user, convert it to an integer using `int()`, add 10, and save the result to the variable `final_number`.

# %%
text_number = input("Enter a number: ")

# 💻 Convert text_number to an integer using int(), 
# add 10, and save the result to the variable final_number:
# final_number = ___


# === AUTOMATED CHECK ===
try:
    import inspect
    cell_code = inspect.getsource(inspect.currentframe())
    student_code = cell_code.split('# ===')[0].strip()
    assert len([l for l in student_code.split('\n') if not l.strip().startswith('#') and l.strip()]) > 1, "You didn't write any code!"
    assert '___' not in student_code, "Fill in the blanks!"
    assert 'final_number' in locals() or 'final_number' in globals(), "❌ [SYSTEM] Error! You didn't create the 'final_number' variable!"
    assert isinstance(final_number, int), f"❌ [SYSTEM] Error! The result must be an integer (int), not {type(final_number)}! Did you use int()?"
    print(f"\n🎉 [SYSTEM] Great job! You successfully converted the text into a real number! Result: {final_number}")
    print("👉 Type 'progress' to the Pi Agent to log your achievement!")
    try:
        import sys
        sys.path.append("/home/justin/Space_Station_Academy/.pi")
        import tracker
        tracker.update_progress("Workbook 1, Lesson 8: Type Casting")
    except Exception:
        pass
except NameError:
    print("\n⚠️ [SYSTEM] Warning! Did you misspell the variable name? Make sure it is exactly: final_number")
except AssertionError as e:
    print("\n🤖 [Pi Agent] Don't be discouraged! Type 'Help' in the side window so we can solve it together!")
    print(f"\n❌ [SYSTEM] Error: {e}")
except Exception as e:
    print("\n🤖 [Pi Agent] Something went wrong with the code. Type 'Help' so we can look at it!")
    print(f"\n❌ [SYSTEM] Error: {e}")

# %% [markdown]
# ## 🎉 MISSION COMPLETED!
#
# Amazing work, **Leonidas**! You have fully activated the consoles and sensor arrays of the Aether station!
#
# ### 🚨 What to do next:
# 1. Make sure you typed **`progress`** to the Pi Agent to record your success.
# 2. Type the command **`/new`** to the Pi Agent to clear its memory.
# 3. Close this notebook and open **`02_Decision_Matrix_eng.ipynb`** to learn how to make logical decisions!
