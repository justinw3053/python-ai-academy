# %% [markdown]
# # Workbook 3: 🔄 Λούπες & Επαναλήψεις
#
# Σε αυτό το τετράδιο θα μάθεις πώς να επαναλαμβάνεις εντολές ξανά και ξανά χρησιμοποιώντας loops (for και while). Αυτό είναι απαραίτητο για σάρωση ραντάρ, συγχρονισμό συστημάτων, και έλεγχο διαδικασιών.

# %% [markdown]
# ### 🎯 Μάθημα 15: For Loops
#
# **Η Ιστορία:** Πρέπει να συγχρονίσουμε τους 4 προωθητήρες του σκάφους.
#
# **Στόχος:** Φτιάξε μια `for` λούπα που επαναλαμβάνει μια εντολή για κάθε προωθητήρα.

# %%
# 💻 Χρησιμοποίησε for loop για να εμφανίσεις 'Συγχρονισμός Προωθητήρα' 4 φορές:
# (Συμβουλή: Χρησιμοποίησε τη μεταβλητή i στη λούπα σου - π.χ.: for i in range(4): )


# === AUTOMATED CHECK ===
try:
    assert 'i' in locals() or 'i' in globals(), "❌ [SYSTEM] Error! Ξέχασες να ορίσεις τη μεταβλητή της λούπας 'i'!"
    assert i == 3, "❌ [SYSTEM] Error! Η λούπα πρέπει να τρέξει ακριβώς 4 φορές (για i από 0 έως 3)!"
    print("\n🎉 [SYSTEM] Great job! Έμαθες να χρησιμοποιείς For Loops!")
    print("👉 Type 'progress' to the Pi Agent!")
    try:
        import sys
        sys.path.append("/home/justin/Space_Station_Academy/.pi")
        import tracker
        tracker.update_progress("Workbook 3, Μάθημα 15: For Loops")
    except Exception:
        pass
except Exception as e:
    print("\n🤖 [Pi Agent] Something went wrong with the code. Type 'Help' so we can look at it!")
    print(f"\n❌ [SYSTEM] Error: {e}")

# %% [markdown]
# ### 🎯 Μάθημα 16: Η συνάρτηση range()
#
# **Η Ιστορία:** Το ραντάρ πρέπει να κάνει ping σταδιακά σε 5 διαφορετικούς τομείς (από το 1 έως το 5).
#
# **Στόχος:** Χρησιμοποίησε τη συνάρτηση `range(1, 6)` μέσα σε μια `for` λούπα για να μετρήσεις από το 1 μέχρι το 5.

# %%
# 💻 Κάνε ping στους τομείς 1 έως 5 χρησιμοποιώντας for και range():
# (Συμβουλή: Χρησιμοποίησε τη μεταβλητή tomeas στη λούπα σου - π.χ.: for tomeas in range(1, 6): )


# === AUTOMATED CHECK ===
try:
    assert 'tomeas' in locals() or 'tomeas' in globals(), "❌ [SYSTEM] Error! Ξέχασες να ορίσεις τη μεταβλητή της λούπας 'tomeas'!"
    assert tomeas == 5, "❌ [SYSTEM] Error! Η λούπα πρέπει να πάει από το 1 έως το 5 (tomeas == 5)!"
    print("\n🎉 [SYSTEM] Φανταστικά! Χρησιμοποίησες τη range() για να κάνεις ping στους τομείς!")
    print("👉 Type 'progress' to the Pi Agent!")
    try:
        import sys
        sys.path.append("/home/justin/Space_Station_Academy/.pi")
        import tracker
        tracker.update_progress("Workbook 3, Μάθημα 16: Range Function")
    except Exception:
        pass
except Exception as e:
    print("\n🤖 [Pi Agent] Something went wrong with the code. Type 'Help' so we can look at it!")
    print(f"\n❌ [SYSTEM] Error: {e}")

# %% [markdown]
# ### 🎯 Μάθημα 17: Διπλές Λούπες (Nested Loops)
#
# **Η Ιστορία:** Πρέπει να σκανάρουμε έναν πίνακα συντεταγμένων 3x3 (γραμμές 1-3 και στήλες 1-3). Φαντάσου το σαν να ελέγχουμε κάθε θέση (στήλη) σε κάθε σειρά ενός Roblox χάρτη!
#
# **Στόχος:** Γράψε μια `for` λούπα μέσα σε μια άλλη `for` λούπα για να εμφανίσεις όλους τους συνδυασμούς (γραμμή, στήλη).

# %%
# 💻 Διπλή λούπα για σκανάρισμα 3x3. 
# Η εξωτερική λούπα μετράει γραμμές, και η εσωτερική στήλες:
# (Συμβουλή: Χρησιμοποίησε τις μεταβλητές grammi και stili - π.χ.: for grammi in range(1, 4): και for stili in range(1, 4): )


# === AUTOMATED CHECK ===
try:
    assert 'grammi' in locals() or 'grammi' in globals(), "❌ [SYSTEM] Error! Ξέχασες να ορίσεις τη μεταβλητή της εξωτερικής λούπας 'grammi'!"
    assert 'stili' in locals() or 'stili' in globals(), "❌ [SYSTEM] Error! Ξέχασες να ορίσεις τη μεταβλητή της εσωτερικής λούπας 'stili'!"
    assert grammi == 3 and stili == 3, "❌ [SYSTEM] Error! Η διπλή λούπα πρέπει να τρέξει για grammi 1 έως 3 και stili 1 έως 3!"
    print("\n🎉 [SYSTEM] Εξαιρετικά! Έκανες σάρωση 3x3 χρησιμοποιώντας Διπλές (Nested) Λούπες!")
    print("👉 Type 'progress' to the Pi Agent!")
    try:
        import sys
        sys.path.append("/home/justin/Space_Station_Academy/.pi")
        import tracker
        tracker.update_progress("Workbook 3, Μάθημα 17: Nested Loops")
    except Exception:
        pass
except Exception as e:
    print("\n🤖 [Pi Agent] Something went wrong with the code. Type 'Help' so we can look at it!")
    print(f"\n❌ [SYSTEM] Error: {e}")

# %% [markdown]
# ### 🎯 Μάθημα 18: While Loops
#
# **Η Ιστορία:** Πρέπει να αδειάσουμε το καύσιμο ασφαλείας μέχρι η ποσότητα να φτάσει στο 0.
#
# **Στόχος:** Χρησιμοποίησε μια λούπα `while` για να μειώνεις το καύσιμο κατά 10 σε κάθε επανάληψη, μέχρι να πάει στο 0.

# %%
kausimo = 50

# 💻 Γράψε το while loop που εμφανίζει το καύσιμο και το μειώνει κατά 10 σε κάθε επανάληψη:
# (Συμβουλή: while kausimo > 0: και μείωσε το kausimo με: kausimo = kausimo - 10 )


# === AUTOMATED CHECK ===
try:
    assert 'kausimo' in locals() or 'kausimo' in globals(), "❌ [SYSTEM] Error! Δεν υπάρχει η μεταβλητή 'kausimo'!"
    assert kausimo == 0, f"❌ [SYSTEM] Error! Η μεταβλητή 'kausimo' πρέπει να φτάσει στο 0, αλλά έχει την τιμή {kausimo}! Μείωσες το καύσιμο κατά 10 σε κάθε επανάληψη;"
    print("\n🎉 [SYSTEM] Great job! Άδειασες το καύσιμο ασφαλείας με μια λούπα While!")
    print("👉 Type 'progress' to the Pi Agent!")
    try:
        import sys
        sys.path.append("/home/justin/Space_Station_Academy/.pi")
        import tracker
        tracker.update_progress("Workbook 3, Μάθημα 18: While Loops")
    except Exception:
        pass
except AssertionError as e:
    print("\n🤖 [Pi Agent] Don't be discouraged! Type 'Help' in the side window so we can solve it together!")
    print(f"\n❌ [SYSTEM] Error: {e}")
except Exception as e:
    print("\n🤖 [Pi Agent] Something went wrong with the code. Type 'Help' so we can look at it!")
    print(f"\n❌ [SYSTEM] Error: {e}")

# %% [markdown]
# ### 🎯 Μάθημα 19: Άπειρες Λούπες & break
#
# **Η Ιστορία:** Μια λούπα `while True` τρέχει για πάντα, εκτός αν τη σταματήσουμε εμείς χειροκίνητα με την εντολή `break`!
#
# **Στόχος:** Φτιάξε μια λούπα `while True` που ζητάει από τον χρήστη να πληκτρολογήσει 'stop' για να σταματήσει.

# %%
# 💻 Χρησιμοποίησε το input() μέσα στη λούπα, και κάνε break αν η είσοδος είναι 'stop':
# (Συμβουλή: Αποθήκευσε την είσοδο του χρήστη σε μια μεταβλητή με όνομα entoli - π.χ.: entoli = input('Δώσε εντολή: ') )


# === AUTOMATED CHECK ===
try:
    assert 'entoli' in locals() or 'entoli' in globals(), "❌ [SYSTEM] Error! Δεν αποθήκευσες την είσοδο του χρήστη στη μεταβλητή με όνομα 'entoli'!"
    assert entoli == 'stop', "❌ [SYSTEM] Error! Η λούπα πρέπει να σταματήσει όταν η μεταβλητή 'entoli' πάρει την τιμή 'stop'!"
    print("\n🎉 [SYSTEM] Great job! Σταμάτησες την άπειρη λούπα χρησιμοποιώντας την εντολή break!")
    print("👉 Type 'progress' to the Pi Agent!")
    try:
        import sys
        sys.path.append("/home/justin/Space_Station_Academy/.pi")
        import tracker
        tracker.update_progress("Workbook 3, Μάθημα 19: Infinite Loops")
    except Exception:
        pass
except Exception as e:
    print("\n🤖 [Pi Agent] Something went wrong with the code. Type 'Help' so we can look at it!")
    print(f"\n❌ [SYSTEM] Error: {e}")

# %% [markdown]
# ### 🎯 Μάθημα 20: Η εντολή continue
#
# **Η Ιστορία:** Θέλουμε να σκανάρουμε τους αριθμούς από το 1 έως το 5, αλλά να προσπεράσουμε (continue) τον αριθμό 3 επειδή έχει θόρυβο.
#
# **Στόχος:** Χρησιμοποίησε `for`, `range()` και `continue` για να εμφανίσεις τους αριθμούς 1, 2, 4, 5 (προσπερνώντας το 3).

# %%
# 💻 Γράψε τον κώδικα εδώ. Αν ο αριθμός είναι 3, χρησιμοποίησε την continue:
# (Συμβουλή: Χρησιμοποίησε τη μεταβλητή arithmos στη λούπα σου - π.χ.: for arithmos in range(1, 6): )


# === AUTOMATED CHECK ===
try:
    assert 'arithmos' in locals() or 'arithmos' in globals(), "❌ [SYSTEM] Error! Ξέχασες να ορίσεις τη μεταβλητή της λούπας 'arithmos'!"
    assert arithmos == 5, "❌ [SYSTEM] Error! Η λούπα πρέπει να πάει από το 1 έως το 5 (arithmos == 5)!"
    print("\n🎉 [SYSTEM] Συγχαρητήρια, Λεωνίδα! Ολοκλήρωσες όλα τα μαθήματα του Workbook 3 χρησιμοποιώντας την continue!")
    print("👉 Type 'progress' to the Pi Agent!")
    try:
        import sys
        sys.path.append("/home/justin/Space_Station_Academy/.pi")
        import tracker
        tracker.update_progress("Workbook 3, Μάθημα 20: Continue Command")
    except Exception:
        pass
except Exception as e:
    print("\n🤖 [Pi Agent] Something went wrong with the code. Type 'Help' so we can look at it!")
    print(f"\n❌ [SYSTEM] Error: {e}")

# %% [markdown]
# ## 🎉 Η ΑΠΟΣΤΟΛΗ ΟΛΟΚΛΗΡΩΘΗΚΕ! (Mission Completed)
#
# Φανταστικά, **Λεωνίδα**! Οι λούπες και οι επαναλήψεις σάρωσαν όλους τους τομείς και εντόπισαν τις βλάβες!
#
# ### 🚨 Τι πρέπει να κάνεις τώρα:
# 1. Γράψε **`πρόοδος`** στον Pi Agent.
# 2. Γράψε **`/new`** για να καθαρίσεις το ιστορικό.
# 3. Άνοιξε το **`04_Data_Arrays.ipynb`** για να οργανώσεις τις αποθήκες και τα λεξικά πληρώματος του σταθμού!
