# %% [markdown]
# # Workbook 4: 📦 Συστοιχίες & Λεξικά Δεδομένων
#
# Ήρθε η ώρα να διαχειριστείς μεγάλες ομάδες δεδομένων! Θα μάθεις πώς να χρησιμοποιείς Λίστες (Lists) για αποθήκευση αποθεμάτων και Λεξικά (Dictionaries) για ταυτότητες και βάσεις δεδομένων.

# %% [markdown]
# ### 💡 Συμβουλή Ασφαλείας AI (Developer Tip):
#
# Ξεκινάμε μια νέα, μεγάλη ενότητα με Λίστες και Λεξικά!
# Πριν γράψεις τον κώδικά σου, **τρέξε την εντολή `/new` στο δεξί τερματικό του Pi Agent** για να καθαρίσεις το ιστορικό και να έχεις τον βοηθό σου 100% συγκεντρωμένο και γρήγορο!

# %% [markdown]
# ### 🎯 Μάθημα 21: Δημιουργία Λίστας
#
# **Η Ιστορία:** Μια λίστα είναι σαν ένα τρένο με βαγόνια όπου μπορούμε να αποθηκεύσουμε πολλά πράγματα μαζί!
#
# **Στόχος:** Φτιάξε μια λίστα με όνομα `ergalia` που περιέχει τα εξής κείμενα: `'κατσαβίδι'`, `'σφυρί'`, `'φακός'`.

# %%
# 💻 Φτιάξε τη λίστα ergalia από κάτω:


# === AUTOMATED CHECK ===
try:
    assert 'ergalia' in locals(), "❌ [SYSTEM] Error! Δεν δημιούργησες τη λίστα 'ergalia'!"
    assert len(ergalia) == 3, f"❌ [SYSTEM] Error! Η λίστα περιέχει {len(ergalia)} στοιχεία, ενώ πρέπει να περιέχει ακριβώς 3!"
    assert "κατσαβίδι" in ergalia and "σφυρί" in ergalia and "φακός" in ergalia, "❌ [SYSTEM] Error! Η λίστα πρέπει να περιέχει ακριβώς τα στοιχεία: 'κατσαβίδι', 'σφυρί', 'φακός'!"
    print("\n🎉 [SYSTEM] Great job! Η λίστα 'ergalia' δημιουργήθηκε σωστά με 3 βαγόνια!")
    print("👉 Type 'progress' to the Pi Agent για να δει τι κατάφερες!")
    
    # Καταγραφή Προόδου
    try:
        import sys
        sys.path.append("/home/justin/Space_Station_Academy/.pi")
        import tracker
        tracker.update_progress("Workbook 4, Μάθημα 21: Lists")
    except Exception:
        pass
except AssertionError as e:
    print("\n🤖 [Pi Agent] Don't be discouraged! Type 'Help' in the side window so we can solve it together!")
    print(f"\n❌ [SYSTEM] Error: {e}")
except Exception as e:
    print("\n🤖 [Pi Agent] Something went wrong with the code. Type 'Help' so we can look at it!")
    print(f"\n❌ [SYSTEM] Error: {e}")

# %% [markdown]
# ### 🎯 Μάθημα 22: Indexing (Θέσεις στη Λίστα)
#
# **Η Ιστορία:** Κάθε αντικείμενο στη λίστα έχει μια θέση (index) που ξεκινάει ΠΑΝΤΑ από το 0!
#
# **Στόχος:** Εμφάνισε το πρώσο αντικείμενο της λίστας (θέση 0) και το τρίτο αντικείμενο (θέση 2).

# %%
syskeues = ["ραντάρ", "ασπίδα", "κινητήρας"]

# 💻 Εμφάνισε το 1ο και το 3ο στοιχείο της λίστας syskeues χρησιμοποιώντας [index]:

# %% [markdown]
# ### 🎯 Μάθημα 23: Μέθοδοι Λίστας (append & remove)
#
# **Η Ιστορία:** Μπορούμε να προσθέσουμε στοιχεία στη λίστα με την `.append()` ή να αφαιρέσουμε με την `.remove()`.
#
# **Στόχος:** Πρόσθεσε το στοιχείο `'λέιζερ'` στη λίστα και αφαίρεσε το στοιχείο `'σφυρί'`.

# %%
oplostasio = ["σφυρί", "κανόνι"]

# 💻 Κάνε append το 'λέιζερ' και remove το 'σφυρί', μετά εμφάνισε τη λίστα:


# === AUTOMATED CHECK ===
try:
    assert 'oplostasio' in locals(), "❌ [SYSTEM] Error! Η λίστα 'oplostasio' δεν υπάρχει!"
    assert "λέιζερ" in oplostasio, "❌ [SYSTEM] Error! Δεν πρόσθεσες το 'λέιζερ' στο οπλοστάσιο!"
    assert "σφυρί" not in oplostasio, "❌ [SYSTEM] Error! Δεν αφαίρεσες το 'σφυρί' από το οπλοστάσιο!"
    print("\n🎉 [SYSTEM] Great job! Το οπλοστάσιο ενημερώθηκε τέλεια με το λέιζερ!")
    print("👉 Type 'progress' to the Pi Agent για να δει τι κατάφερες!")
    
    # Καταγραφή Προόδου
    try:
        import sys
        sys.path.append("/home/justin/Space_Station_Academy/.pi")
        import tracker
        tracker.update_progress("Workbook 4, Μάθημα 23: List Methods")
    except Exception:
        pass
except AssertionError as e:
    print("\n🤖 [Pi Agent] Don't be discouraged! Type 'Help' in the side window so we can solve it together!")
    print(f"\n❌ [SYSTEM] Error: {e}")
except Exception as e:
    print("\n🤖 [Pi Agent] Something went wrong with the code. Type 'Help' so we can look at it!")
    print(f"\n❌ [SYSTEM] Error: {e}")

# %% [markdown]
# ### 🎯 Μάθημα 24: Λεξικά (Dictionaries)
#
# **Η Ιστορία:** Ένα λεξικό (dictionary) αποθηκεύει πληροφορίες σε ζευγάρια: Κλειδί (Key) και Τιμή (Value) - σαν μια ταυτότητα!
#
# **Στόχος:** Φτιάξε ένα λεξικό με όνομα `kyvernitis` με κλειδιά `'onoma'` (τιμή `'Αλέξης'`) και `'vathmos'` (τιμή `'Λοχαγός'`). Μετά εκτύπωσε μόνο το όνομα.

# %%
# 💻 Φτιάξε το λεξικό kyvernitis από κάτω, μετά εκτύπωσε μόνο το όνομα:


# === AUTOMATED CHECK ===
try:
    assert 'kyvernitis' in locals(), "❌ [SYSTEM] Error! Δεν δημιούργησες το λεξικό 'kyvernitis'!"
    assert kyvernitis.get("onoma") == "Αλέξης", f"❌ [SYSTEM] Error! Το κλειδί 'onoma' πρέπει να έχει τιμή 'Αλέξης', όχι '{kyvernitis.get('onoma')}'!"
    assert kyvernitis.get("vathmos") == "Λοχαγός", f"❌ [SYSTEM] Error! Το κλειδί 'vathmos' πρέπει να έχει τιμή 'Λοχαγός', όχι '{kyvernitis.get('vathmos')}'!"
    print("\n🎉 [SYSTEM] Great job! Το λεξικό του κυβερνήτη δημιουργήθηκε με επιτυχία!")
    print("👉 Type 'progress' to the Pi Agent για να δει τι κατάφερες!")
    
    # Καταγραφή Προόδου
    try:
        import sys
        sys.path.append("/home/justin/Space_Station_Academy/.pi")
        import tracker
        tracker.update_progress("Workbook 4, Μάθημα 24: Dictionaries")
    except Exception:
        pass
except AssertionError as e:
    print("\n🤖 [Pi Agent] Don't be discouraged! Type 'Help' in the side window so we can solve it together!")
    print(f"\n❌ [SYSTEM] Error: {e}")
except Exception as e:
    print("\n🤖 [Pi Agent] Something went wrong with the code. Type 'Help' so we can look at it!")
    print(f"\n❌ [SYSTEM] Error: {e}")

# %% [markdown]
# ### 🎯 Μάθημα 25: Ενημέρωση Λεξικού
#
# **Η Ιστορία:** Μπορούμε να αλλάξουμε τιμές σε ένα λεξικό ή να προσθέσουμε νέα κλειδιά πολύ εύκολα.
#
# **Στόχος:** Άλλαξε την κατάσταση της ασπίδας σε `'ΕΝΕΡΓΗ'` και πρόσθεσε ένα νέο κλειδί `'isxis'` με τιμή `100`.

# %%
aspida_stats = {
    "katastasi": "ΑΝΕΝΕΡΓΗ"
}

# 💻 Άλλαξε την κατάσταση σε 'ΕΝΕΡΓΗ' και πρόσθεσε το κλειδί 'isxis' με τιμή 100, μετά εμφάνισε το λεξικό:


# === AUTOMATED CHECK ===
try:
    assert aspida_stats.get("katastasi") == "ΕΝΕΡΓΗ", "❌ [SYSTEM] Error! Η κατάσταση της ασπίδας πρέπει να είναι 'ΕΝΕΡΓΗ'!"
    assert aspida_stats.get("isxis") == 100, "❌ [SYSTEM] Error! Δεν πρόσθεσες το κλειδί 'isxis' με τιμή 100!"
    print("\n🎉 [SYSTEM] Great job! Οι ασπίδες αναβαθμίστηκαν στο 100%!")
    print("👉 Type 'progress' to the Pi Agent για να δει τι κατάφερες!")
    
    # Καταγραφή Προόδου
    try:
        import sys
        sys.path.append("/home/justin/Space_Station_Academy/.pi")
        import tracker
        tracker.update_progress("Workbook 4, Μάθημα 25: Dict Methods")
    except Exception:
        pass
except AssertionError as e:
    print("\n🤖 [Pi Agent] Don't be discouraged! Type 'Help' in the side window so we can solve it together!")
    print(f"\n❌ [SYSTEM] Error: {e}")
except Exception as e:
    print("\n🤖 [Pi Agent] Something went wrong with the code. Type 'Help' so we can look at it!")
    print(f"\n❌ [SYSTEM] Error: {e}")

# %% [markdown]
# ### 🎯 Μάθημα 26: Μέγεθος Συλλογών (Η συνάρτηση len())
#
# **Η Ιστορία:** Πώς μπορούμε να μάθουμε πόσα πράγματα έχουμε μέσα σε μια λίστα ή ένα λεξικό; Χρησιμοποιούμε τη συνάρτηση `len()`. Είναι σαν να μετράμε τα αντικείμενα που βάλαμε στα ντουλάπια μας!
#
# **Στόχος:** Υπολόγισε το μέγεθος της λίστας `ergalia_ekseleysis` χρησιμοποιώντας την `len()` και αποθήκευσέ το στη μεταβλητή `plithos_ergaleion`. Μετά, εμφάνισε το αποτέλεσμα με print().

# %%
ergalia_ekseleysis = ["σφυρί", "κλειδί", "κατσαβίδι", "σκοινί", "γάντια"]

# 💻 Βρες το πλήθος των εργαλείων χρησιμοποιώντας την len() και αποθήκευσέ το στη plithos_ergaleion:
# plithos_ergaleion = ...


# === AUTOMATED CHECK ===
try:
    assert 'plithos_ergaleion' in locals() or 'plithos_ergaleion' in globals(), "❌ [SYSTEM] Error! Δεν δημιούργησες τη μεταβλητή 'plithos_ergaleion'!"
    assert plithos_ergaleion == 5, f"❌ [SYSTEM] Error! Το πλήθος των εργαλείων πρέπει να είναι 5, όχι {plithos_ergaleion}!"
    print("\n🎉 [SYSTEM] Great job! Μέτρησες σωστά τα εργαλεία με την len()!")
    print("👉 Type 'progress' to the Pi Agent για να δει τι κατάφερες!")
    
    # Καταγραφή Προόδου
    try:
        import sys
        sys.path.append("/home/justin/Space_Station_Academy/.pi")
        import tracker
        tracker.update_progress("Workbook 4, Μάθημα 26: Collection Size")
    except Exception:
        pass
except NameError:
    print("\n⚠️ [SYSTEM] Προσοχή! Μήπως έγραψες λάθος το όνομα της μεταβλητής ή ξέχασες να την ορίσεις; Σιγουρέψου ότι γράφεται ακριβώς: plithos_ergaleion")
except AssertionError as e:
    print("\n🤖 [Pi Agent] Don't be discouraged! Type 'Help' in the side window so we can solve it together!")
    print(f"\n❌ [SYSTEM] Error: {e}")
except Exception as e:
    print("\n🤖 [Pi Agent] Something went wrong with the code. Type 'Help' so we can look at it!")
    print(f"\n❌ [SYSTEM] Error: {e}")

# %% [markdown]
# ## 🎉 Η ΑΠΟΣΤΟΛΗ ΟΛΟΚΛΗΡΩΘΗΚΕ! (Mission Completed)
#
# Μπράβο, **Λεωνίδα**! Οργάνωσες τέλεια τις αποθήκες και τα αρχεία του πληρώματος με Λίστες και Λεξικά!
#
# ### 🚨 Τι πρέπει να κάνεις τώρα:
# 1. Γράψε **`πρόοδος`** στον Pi Agent.
# 2. Γράψε **`/new`** για να ανανεώσεις τον βοηθό σου.
# 3. Άνοιξε το **`05_Engineering_Core.ipynb`** για να γράψεις τις δικές σου συναρτήσεις επισκευής!
